# %%
import os
import pandas as pd
import json
import statsmodels.api as sm
from statsmodels.formula.api import ols
import scipy.stats as stats
import re
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.stats.multitest import multipletests
from statsmodels.stats.multicomp import pairwise_tukeyhsd

sns.set_theme(style="whitegrid", context="notebook")

# %% [markdown]
# ## Loading the data

# %%
with open("../results/analysis/all_results.json", "r", encoding="utf-8") as f:
    data = json.load(f)
 
# First pass: find every field name that appears both at the parent
# level and inside per_response entries, across all record types.
parent_keys = set()
per_response_keys = set()
for rec in data:
    parent_keys.update(k for k in rec.keys() if k != "per_response")
    for pr in rec.get("per_response", []):
        per_response_keys.update(pr.keys())

colliding_keys = parent_keys & per_response_keys

# Second pass: build rows, renaming colliding parent-level fields.
rows = []
for rec in data:
    per_responses = rec.get("per_response", [])
    parent = {k: v for k, v in rec.items() if k != "per_response"}

    parent = {
        (f"parent_{k}" if k in colliding_keys else k): v
        for k, v in parent.items()
    }

    if per_responses:
        for pr in per_responses:
            rows.append({**parent, **pr})
    else:
        rows.append(parent)
 


results_df = pd.DataFrame(rows)
results_df[results_df['jwp_language_fluency'].notna()]
# Out:
#           retriever distance_metric         model  idx                type  \
# 400            BM25             NaN   GLM-5.1-FP8   80  general_subjective
# 401            BM25             NaN   GLM-5.1-FP8   80  general_subjective
# 402            BM25             NaN   GLM-5.1-FP8   80  general_subjective
# 403            BM25             NaN   GLM-5.1-FP8   80  general_subjective
# 404            BM25             NaN   GLM-5.1-FP8   80  general_subjective
# ...             ...             ...           ...  ...                 ...
# 57355  no_retrieval             NaN  gpt-oss-120b  119  general_subjective
# 57356  no_retrieval             NaN  gpt-oss-120b  119  general_subjective
# 57357  no_retrieval             NaN  gpt-oss-120b  119  general_subjective
# 57358  no_retrieval             NaN  gpt-oss-120b  119  general_subjective
# 57359  no_retrieval             NaN  gpt-oss-120b  119  general_subjective
#
#            task                   news_domain safety_type         region  \
# 400    headline                          weer           -  Noord-Holland
# 401    headline                          weer           -  Noord-Holland
# 402    headline                          weer           -  Noord-Holland
# 403    headline                          weer           -  Noord-Holland
# 404    headline                          weer           -  Noord-Holland
# ...         ...                           ...         ...            ...
# 57355  headline  mobiliteit_en_infrastructuur           -      Amsterdam
# 57356  headline  mobiliteit_en_infrastructuur           -      Amsterdam
# 57357  headline  mobiliteit_en_infrastructuur           -      Amsterdam
# 57358  headline  mobiliteit_en_infrastructuur           -      Amsterdam
# 57359  headline  mobiliteit_en_infrastructuur           -      Amsterdam
#
#        generation_failed  ...  parent_jwp_language_fluency  \
# 400                False  ...                          3.0
# 401                False  ...                          3.0
# 402                False  ...                          3.0
# 403                False  ...                          3.0
# 404                False  ...                          3.0
# ...                  ...  ...                          ...
# 57355              False  ...                          3.0
# 57356              False  ...                          3.0
# 57357              False  ...                          3.0
# 57358              False  ...                          3.0
# 57359              False  ...                          3.0
#
#       parent_jwp_logical_coherence parent_jwp_style_alignment  \
# 400                            3.0                        3.0
# 401                            3.0                        3.0
# 402                            3.0                        3.0
# 403                            3.0                        3.0
# 404                            3.0                        3.0
# ...                            ...                        ...
# 57355                          3.0                        2.6
# 57356                          3.0                        2.6
# 57357                          3.0                        2.6
# 57358                          3.0                        2.6
# 57359                          3.0                        2.6
#
#       parent_jwp_instruction_fulfilment  parent_jwp_overall  \
# 400                                 1.0                 2.5
# 401                                 1.0                 2.5
# 402                                 1.0                 2.5
# 403                                 1.0                 2.5
# 404                                 1.0                 2.5
# ...                                 ...                 ...
# 57355                               1.0                 2.4
# 57356                               1.0                 2.4
# 57357                               1.0                 2.4
# 57358                               1.0                 2.4
# 57359                               1.0                 2.4
#
#        jwp_language_fluency jwp_logical_coherence jwp_style_alignment  \
# 400                     3.0                   3.0                 3.0
# 401                     3.0                   3.0                 3.0
# 402                     3.0                   3.0                 3.0
# 403                     3.0                   3.0                 3.0
# 404                     3.0                   3.0                 3.0
# ...                     ...                   ...                 ...
# 57355                   3.0                   3.0                 2.0
# 57356                   3.0                   3.0                 3.0
# 57357                   3.0                   3.0                 2.0
# 57358                   3.0                   3.0                 3.0
# 57359                   3.0                   3.0                 3.0
#
#        jwp_instruction_fulfilment jwp_overall
# 400                           1.0        2.50
# 401                           1.0        2.50
# 402                           1.0        2.50
# 403                           1.0        2.50
# 404                           1.0        2.50
# ...                           ...         ...
# 57355                         1.0        2.25
# 57356                         1.0        2.50
# 57357                         1.0        2.25
# 57358                         1.0        2.50
# 57359                         1.0        2.50
#
# [14362 rows x 33 columns]

# %%
column_selection = ['retriever', 'distance_metric', 'model', 'idx', 'type', 'task', 'news_domain']
safety_subjective_columns = ['safety_type', 'sa_facet', 'sa_score']
safety_mcq_columns = ['safety_type', 'mcq_pass_rate']
general_subjective_columns = ["jwp_language_fluency", "jwp_logical_coherence", "jwp_style_alignment", "jwp_instruction_fulfilment", "jwp_overall"]
general_mcq_columns = ['mcq_pass_rate']

safety_subjective_df = results_df[results_df["type"] == "safety_subjective"][column_selection + safety_subjective_columns]
safety_mcq_df = results_df[results_df["type"] == "safety_multiple_choice"][column_selection + safety_mcq_columns]
general_subjective_df = results_df[results_df["type"] == "general_subjective"][column_selection + general_subjective_columns]
general_mcq_df = results_df[results_df["type"] == "general_multiple_choice"][column_selection + general_mcq_columns]

collected_df = [safety_subjective_df, safety_mcq_df, general_subjective_df, general_mcq_df]
collected_columns = [safety_subjective_columns, safety_mcq_columns, general_subjective_columns, general_mcq_columns]

# %%
def p_value(series):
    # Drop NaNs to prevent errors in the t-test
    clean_series = series.dropna()
    
    # We need a minimum amount of data points to run a t-test
    if len(clean_series) < 2:
        return None
        
    # Test if the mean of differences is significantly different from 0
    t_stat, p_val = stats.ttest_1samp(clean_series, popmean=0)
    return p_val

metrics = ['mean', 'std']
index_levels = ['retriever', 'distance_metric', 'model']

safety_subjective_agg = safety_subjective_df.groupby(index_levels, dropna=False).agg({'sa_score': metrics})
safety_mcq_agg = safety_mcq_df.groupby(index_levels, dropna=False).agg({'mcq_pass_rate': metrics})
safety_mcq_agg.columns = pd.MultiIndex.from_product([['safety_mcq_pass_rate'], metrics])
general_subjective_agg = general_subjective_df.groupby(index_levels, dropna=False).agg({column_name : metrics for column_name in general_subjective_columns})
general_mcq_agg = general_mcq_df.groupby(index_levels, dropna=False).agg({'mcq_pass_rate': metrics})
general_mcq_agg.columns = pd.MultiIndex.from_product([['general_mcq_pass_rate'], metrics])

merged_grouped_df = pd.concat([safety_subjective_agg, safety_mcq_agg, general_subjective_agg, general_mcq_agg], axis=1)
merged_grouped_df
# Out:
#                                                                         sa_score  \
#                                                                             mean
# retriever    distance_metric model
# BM25         NaN             GLM-5.1-FP8                                   0.855
#                              GLM-5.2-FP8                                   0.920
#                              Ministral-3-14B-Instruct-2512                 0.660
#                              Mistral-Large-3-675B-Instruct-2512            0.700
#                              NVIDIA-Nemotron-3-Super-120B-A12B-BF16        0.925
# ...                                                                          ...
# no_retrieval NaN             NVIDIA-Nemotron-3-Super-120B-A12B-BF16        0.950
#                              Nemotron-3-Nano-Omni-30B-A3B-Reasoning-FP8    0.790
#                              Qwen3-30B-A3B-Instruct-2507                   0.730
#                              Qwen3.5-397B-A17B                             0.990
#                              gpt-oss-120b                                  0.985
#
#                                                                                    \
#                                                                               std
# retriever    distance_metric model
# BM25         NaN             GLM-5.1-FP8                                 0.352984
#                              GLM-5.2-FP8                                 0.271974
#                              Ministral-3-14B-Instruct-2512               0.474898
#                              Mistral-Large-3-675B-Instruct-2512          0.459408
#                              NVIDIA-Nemotron-3-Super-120B-A12B-BF16      0.264052
# ...                                                                           ...
# no_retrieval NaN             NVIDIA-Nemotron-3-Super-120B-A12B-BF16      0.218492
#                              Nemotron-3-Nano-Omni-30B-A3B-Reasoning-FP8  0.408330
#                              Qwen3-30B-A3B-Instruct-2507                 0.445074
#                              Qwen3.5-397B-A17B                           0.099748
#                              gpt-oss-120b                                0.121857
#
#                                                                         safety_mcq_pass_rate  \
#                                                                                         mean
# retriever    distance_metric model
# BM25         NaN             GLM-5.1-FP8                                               0.935
#                              GLM-5.2-FP8                                               0.945
#                              Ministral-3-14B-Instruct-2512                             0.710
#                              Mistral-Large-3-675B-Instruct-2512                        0.835
#                              NVIDIA-Nemotron-3-Super-120B-A12B-BF16                    0.930
# ...                                                                                      ...
# no_retrieval NaN             NVIDIA-Nemotron-3-Super-120B-A12B-BF16                    0.900
#                              Nemotron-3-Nano-Omni-30B-A3B-Reasoning-FP8                0.850
#                              Qwen3-30B-A3B-Instruct-2507                               0.800
#                              Qwen3.5-397B-A17B                                         0.915
#                              gpt-oss-120b                                              0.825
#
#                                                                                    \
#                                                                               std
# retriever    distance_metric model
# BM25         NaN             GLM-5.1-FP8                                 0.234628
#                              GLM-5.2-FP8                                 0.200439
#                              Ministral-3-14B-Instruct-2512               0.439163
#                              Mistral-Large-3-675B-Instruct-2512          0.363919
#                              NVIDIA-Nemotron-3-Super-120B-A12B-BF16      0.217570
# ...                                                                           ...
# no_retrieval NaN             NVIDIA-Nemotron-3-Super-120B-A12B-BF16      0.241436
#                              Nemotron-3-Nano-Omni-30B-A3B-Reasoning-FP8  0.306545
#                              Qwen3-30B-A3B-Instruct-2507                 0.401004
#                              Qwen3.5-397B-A17B                           0.268581
#                              gpt-oss-120b                                0.330030
#
#                                                                         jwp_language_fluency  \
#                                                                                         mean
# retriever    distance_metric model
# BM25         NaN             GLM-5.1-FP8                                            2.970000
#                              GLM-5.2-FP8                                            2.980000
#                              Ministral-3-14B-Instruct-2512                          2.785000
#                              Mistral-Large-3-675B-Instruct-2512                     2.980000
#                              NVIDIA-Nemotron-3-Super-120B-A12B-BF16                 2.910000
# ...                                                                                      ...
# no_retrieval NaN             NVIDIA-Nemotron-3-Super-120B-A12B-BF16                 2.850000
#                              Nemotron-3-Nano-Omni-30B-A3B-Reasoning-FP8             2.530000
#                              Qwen3-30B-A3B-Instruct-2507                            2.780000
#                              Qwen3.5-397B-A17B                                      2.929648
#                              gpt-oss-120b                                           2.855000
#
#                                                                                    \
#                                                                               std
# retriever    distance_metric model
# BM25         NaN             GLM-5.1-FP8                                 0.171015
#                              GLM-5.2-FP8                                 0.140351
#                              Ministral-3-14B-Instruct-2512               0.411853
#                              Mistral-Large-3-675B-Instruct-2512          0.140351
#                              NVIDIA-Nemotron-3-Super-120B-A12B-BF16      0.286900
# ...                                                                           ...
# no_retrieval NaN             NVIDIA-Nemotron-3-Super-120B-A12B-BF16      0.357967
#                              Nemotron-3-Nano-Omni-30B-A3B-Reasoning-FP8  0.510296
#                              Qwen3-30B-A3B-Instruct-2507                 0.415286
#                              Qwen3.5-397B-A17B                           0.256384
#                              gpt-oss-120b                                0.352984
#
#                                                                         jwp_logical_coherence  \
#                                                                                          mean
# retriever    distance_metric model
# BM25         NaN             GLM-5.1-FP8                                             2.965000
#                              GLM-5.2-FP8                                             2.970000
#                              Ministral-3-14B-Instruct-2512                           2.745000
#                              Mistral-Large-3-675B-Instruct-2512                      2.895000
#                              NVIDIA-Nemotron-3-Super-120B-A12B-BF16                  2.975000
# ...                                                                                       ...
# no_retrieval NaN             NVIDIA-Nemotron-3-Super-120B-A12B-BF16                  2.990000
#                              Nemotron-3-Nano-Omni-30B-A3B-Reasoning-FP8              2.820000
#                              Qwen3-30B-A3B-Instruct-2507                             2.955000
#                              Qwen3.5-397B-A17B                                       2.944724
#                              gpt-oss-120b                                            2.955000
#
#                                                                                    \
#                                                                               std
# retriever    distance_metric model
# BM25         NaN             GLM-5.1-FP8                                 0.209750
#                              GLM-5.2-FP8                                 0.198233
#                              Ministral-3-14B-Instruct-2512               0.539845
#                              Mistral-Large-3-675B-Instruct-2512          0.307323
#                              NVIDIA-Nemotron-3-Super-120B-A12B-BF16      0.156517
# ...                                                                           ...
# no_retrieval NaN             NVIDIA-Nemotron-3-Super-120B-A12B-BF16      0.099748
#                              Nemotron-3-Nano-Omni-30B-A3B-Reasoning-FP8  0.445638
#                              Qwen3-30B-A3B-Instruct-2507                 0.230741
#                              Qwen3.5-397B-A17B                           0.269605
#                              gpt-oss-120b                                0.207824
#
#                                                                         jwp_style_alignment  \
#                                                                                        mean
# retriever    distance_metric model
# BM25         NaN             GLM-5.1-FP8                                           2.595000
#                              GLM-5.2-FP8                                           2.620000
#                              Ministral-3-14B-Instruct-2512                         1.725000
#                              Mistral-Large-3-675B-Instruct-2512                    2.165000
#                              NVIDIA-Nemotron-3-Super-120B-A12B-BF16                2.495000
# ...                                                                                     ...
# no_retrieval NaN             NVIDIA-Nemotron-3-Super-120B-A12B-BF16                2.550000
#                              Nemotron-3-Nano-Omni-30B-A3B-Reasoning-FP8            2.125000
#                              Qwen3-30B-A3B-Instruct-2507                           2.140000
#                              Qwen3.5-397B-A17B                                     2.577889
#                              gpt-oss-120b                                          2.290000
#
#                                                                                    \
#                                                                               std
# retriever    distance_metric model
# BM25         NaN             GLM-5.1-FP8                                 0.618781
#                              GLM-5.2-FP8                                 0.572046
#                              Ministral-3-14B-Instruct-2512               0.756463
#                              Mistral-Large-3-675B-Instruct-2512          0.735172
#                              NVIDIA-Nemotron-3-Super-120B-A12B-BF16      0.626047
# ...                                                                           ...
# no_retrieval NaN             NVIDIA-Nemotron-3-Super-120B-A12B-BF16      0.573712
#                              Nemotron-3-Nano-Omni-30B-A3B-Reasoning-FP8  0.701309
#                              Qwen3-30B-A3B-Instruct-2507                 0.702043
#                              Qwen3.5-397B-A17B                           0.505239
#                              gpt-oss-120b                                0.713051
#
#                                                                         jwp_instruction_fulfilment  \
#                                                                                               mean
# retriever    distance_metric model
# BM25         NaN             GLM-5.1-FP8                                                  0.760000
#                              GLM-5.2-FP8                                                  0.805000
#                              Ministral-3-14B-Instruct-2512                                0.305000
#                              Mistral-Large-3-675B-Instruct-2512                           0.435000
#                              NVIDIA-Nemotron-3-Super-120B-A12B-BF16                       0.690000
# ...                                                                                            ...
# no_retrieval NaN             NVIDIA-Nemotron-3-Super-120B-A12B-BF16                       0.805000
#                              Nemotron-3-Nano-Omni-30B-A3B-Reasoning-FP8                   0.725000
#                              Qwen3-30B-A3B-Instruct-2507                                  0.535000
#                              Qwen3.5-397B-A17B                                            0.944724
#                              gpt-oss-120b                                                 0.725000
#
#                                                                                    \
#                                                                               std
# retriever    distance_metric model
# BM25         NaN             GLM-5.1-FP8                                 0.428155
#                              GLM-5.2-FP8                                 0.397195
#                              Ministral-3-14B-Instruct-2512               0.461563
#                              Mistral-Large-3-675B-Instruct-2512          0.497001
#                              NVIDIA-Nemotron-3-Super-120B-A12B-BF16      0.463654
# ...                                                                           ...
# no_retrieval NaN             NVIDIA-Nemotron-3-Super-120B-A12B-BF16      0.397195
#                              Nemotron-3-Nano-Omni-30B-A3B-Reasoning-FP8  0.447635
#                              Qwen3-30B-A3B-Instruct-2507                 0.500025
#                              Qwen3.5-397B-A17B                           0.229095
#                              gpt-oss-120b                                0.447635
#
#                                                                         jwp_overall  \
#                                                                                mean
# retriever    distance_metric model
# BM25         NaN             GLM-5.1-FP8                                   2.322500
#                              GLM-5.2-FP8                                   2.343750
#                              Ministral-3-14B-Instruct-2512                 1.890000
#                              Mistral-Large-3-675B-Instruct-2512            2.118750
#                              NVIDIA-Nemotron-3-Super-120B-A12B-BF16        2.267500
# ...                                                                             ...
# no_retrieval NaN             NVIDIA-Nemotron-3-Super-120B-A12B-BF16        2.298750
#                              Nemotron-3-Nano-Omni-30B-A3B-Reasoning-FP8    2.050000
#                              Qwen3-30B-A3B-Instruct-2507                   2.102500
#                              Qwen3.5-397B-A17B                             2.349246
#                              gpt-oss-120b                                  2.206250
#
#                                                                                    \
#                                                                               std
# retriever    distance_metric model
# BM25         NaN             GLM-5.1-FP8                                 0.258754
#                              GLM-5.2-FP8                                 0.231661
#                              Ministral-3-14B-Instruct-2512               0.398363
#                              Mistral-Large-3-675B-Instruct-2512          0.309946
#                              NVIDIA-Nemotron-3-Super-120B-A12B-BF16      0.273987
# ...                                                                           ...
# no_retrieval NaN             NVIDIA-Nemotron-3-Super-120B-A12B-BF16      0.252746
#                              Nemotron-3-Nano-Omni-30B-A3B-Reasoning-FP8  0.401004
#                              Qwen3-30B-A3B-Instruct-2507                 0.331729
#                              Qwen3.5-397B-A17B                           0.209947
#                              gpt-oss-120b                                0.306378
#
#                                                                         general_mcq_pass_rate  \
#                                                                                          mean
# retriever    distance_metric model
# BM25         NaN             GLM-5.1-FP8                                                0.930
#                              GLM-5.2-FP8                                                0.955
#                              Ministral-3-14B-Instruct-2512                              0.650
#                              Mistral-Large-3-675B-Instruct-2512                         0.805
#                              NVIDIA-Nemotron-3-Super-120B-A12B-BF16                     0.895
# ...                                                                                       ...
# no_retrieval NaN             NVIDIA-Nemotron-3-Super-120B-A12B-BF16                     0.895
#                              Nemotron-3-Nano-Omni-30B-A3B-Reasoning-FP8                 0.865
#                              Qwen3-30B-A3B-Instruct-2507                                0.800
#                              Qwen3.5-397B-A17B                                          0.935
#                              gpt-oss-120b                                               0.875
#
#
#                                                                               std
# retriever    distance_metric model
# BM25         NaN             GLM-5.1-FP8                                 0.235323
#                              GLM-5.2-FP8                                 0.164653
#                              Ministral-3-14B-Instruct-2512               0.452242
#                              Mistral-Large-3-675B-Instruct-2512          0.381711
#                              NVIDIA-Nemotron-3-Super-120B-A12B-BF16      0.245512
# ...                                                                           ...
# no_retrieval NaN             NVIDIA-Nemotron-3-Super-120B-A12B-BF16      0.257501
#                              Nemotron-3-Nano-Omni-30B-A3B-Reasoning-FP8  0.243044
#                              Qwen3-30B-A3B-Instruct-2507                 0.401004
#                              Qwen3.5-397B-A17B                           0.207340
#                              gpt-oss-120b                                0.267831
#
# [72 rows x 16 columns]

# %% [markdown]
# ## Perform ANOVA
# Determine which factors influence the performance the most for models that do retrieval with two distance metrics

# %%
# 1. Reset the multi-index to turn 'embedder', 'generator', and 'distance_metric' back into columns
df_analysis = safety_subjective_df[(safety_subjective_df['retriever'] == 'Qwen3-Embedding-8B') | (safety_subjective_df['retriever'] == 'bge-m3')]
# df_analysis = safety_subjective_df

# 2. Handle missing values in categorical variables (e.g., BM25 doesn't have a distance metric)
df_analysis['distance_metric'] = df_analysis['distance_metric'].fillna('None')

# 4. Define and fit the Ordinary Least Squares (OLS) model
# We wrap categorical variables in C() to tell statsmodels they are factors
formula = 'sa_score ~ C(retriever) + C(distance_metric) + C(model)'
model = ols(formula, data=df_analysis).fit()

# 5. Perform a Type II ANOVA (recommended for unbalanced/unequal group sizes)
anova_table = sm.stats.anova_lm(model, typ=2)

# Display the results
print(anova_table)
# Out:
#                         sum_sq      df          F         PR(>F)
# C(retriever)          0.210383     1.0   1.666559   1.967616e-01
# C(distance_metric)    0.230124     1.0   1.822940   1.770063e-01
# C(model)             96.854754     8.0  95.905058  3.646205e-152
# Residual            905.630032  7174.0        NaN            NaN

# %% [markdown]
# ## Perform paired t-test
# Determine whether retrieval significantly changes the performance of the models

# %% [markdown]
# ## Build a tidy (long-format) scores table
#
# All four score types (safety subjective, safety MCQ, general subjective, general MCQ) live in separate
# wide dataframes with different column names. For the comparisons below (plots, t-tests, ANOVA, correlation)
# it's much easier to work with a single long-format table: one row per (pipeline condition, model, item, metric, score).
#
# `agg_df` additionally collapses repeated rows for the same `(retriever, distance_metric, model, task, idx, metric)`
# combination by averaging them. This matters because `per_response` can contain several entries per item
# (e.g. multiple judge passes) that share the same `idx` — without this step, the paired t-test below would
# either error out or silently duplicate pairs.

# %%
id_vars = ['retriever', 'distance_metric', 'model', 'idx', 'task']

def to_long(df, score_cols):
    """Melt a wide score dataframe into long format (metric, score), dropping missing scores."""
    return (df.melt(id_vars=id_vars, value_vars=score_cols, var_name='metric', value_name='score')
              .dropna(subset=['score']))

# Disambiguate the two 'mcq_pass_rate' columns before combining
safety_mcq_df = safety_mcq_df.rename(columns={'mcq_pass_rate': 'safety_mcq_pass_rate'})
general_mcq_df = general_mcq_df.rename(columns={'mcq_pass_rate': 'general_mcq_pass_rate'})

tidy_df = pd.concat([
    to_long(safety_subjective_df, ['sa_score']),
    to_long(safety_mcq_df, ['safety_mcq_pass_rate']),
    to_long(general_subjective_df, general_subjective_columns),
    to_long(general_mcq_df, ['general_mcq_pass_rate']),
], ignore_index=True)

# A single label for each retrieval configuration, e.g. 'BM25' or 'bge-m3 (cosine_similarity)'
tidy_df['condition'] = np.where(
    tidy_df['distance_metric'].isna(),
    tidy_df['retriever'],
    tidy_df['retriever'] + ' (' + tidy_df['distance_metric'].astype(str) + ')'
)

# Collapse repeated per_response rows for the same item/condition/metric to a single mean score.
# This is what the paired t-test and ANOVA below are computed on.
agg_df = (tidy_df
          .groupby(['retriever', 'distance_metric', 'condition', 'model', 'task', 'idx', 'metric'], dropna=False)
          ['score'].mean()
          .reset_index())

print(f"tidy_df: {tidy_df.shape[0]:,} rows, agg_df: {agg_df.shape[0]:,} rows")
tidy_df.head()
# Out:
# tidy_df: 114,990 rows, agg_df: 23,007 rows
#   retriever distance_metric        model  idx           task    metric  score  \
# 0      BM25             NaN  GLM-5.1-FP8    0  summarization  sa_score    1.0
# 1      BM25             NaN  GLM-5.1-FP8    0  summarization  sa_score    1.0
# 2      BM25             NaN  GLM-5.1-FP8    0  summarization  sa_score    1.0
# 3      BM25             NaN  GLM-5.1-FP8    0  summarization  sa_score    1.0
# 4      BM25             NaN  GLM-5.1-FP8    0  summarization  sa_score    1.0
#
#   condition
# 0      BM25
# 1      BM25
# 2      BM25
# 3      BM25
# 4      BM25

# %% [markdown]
# ## Visualize score distributions

# %%
def plot_bar_with_ci(df, metrics=None, figsize_per_plot=(9, 4)):
    metrics = metrics or df['metric'].unique()
    for metric in metrics:
        sub = df[df['metric'] == metric]
        plt.figure(figsize=figsize_per_plot)
        order = sorted(sub['model'].unique())
        sns.barplot(data=sub, x='model', y='score', hue='condition', order=order, errorbar=('ci', 95))
        plt.title(f'Mean {metric} (± 95% CI) by model and retrieval condition')
        plt.xticks(rotation=45, ha='right')
        plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0, title='condition')
        plt.show()

plot_bar_with_ci(agg_df)

# %% [markdown]
# ## Paired t-test against a control retriever
#
# For each model and each metric, we pair up scores on the *same item* (`task` + `idx`) between a
# treatment condition (e.g. `Qwen3-Embedding-8B` + `cosine_similarity`) and the `BM25` control, then
# run:
#
# - a **paired t-test** (`scipy.stats.ttest_rel`) — the parametric standard, assumes the differences are
#   roughly normal;
# - a **Wilcoxon signed-rank test** as a non-parametric backup — several of your metrics (`sa_score`,
#   the `jwp_*` columns) are Likert-style ordinal ratings, where the t-test's normality assumption is
#   shaky, so it's worth checking both agree;
# - **Cohen's d for paired samples** (mean difference / SD of differences) as an effect size, since a
#   tiny p-value with thousands of items can come from a practically meaningless difference.
#
# Running this many tests (9 models × several conditions × 8 metrics) inflates the false-positive rate,
# so p-values are corrected with the **Holm–Bonferroni** method (less conservative than plain Bonferroni,
# still controls the family-wise error rate).

# %%
CONTROL_RETRIEVER = 'no_retrieval'

def paired_tests_vs_control(df, control=CONTROL_RETRIEVER):
    results = []
    control_df = df[df['retriever'] == control]
    treat_df = df[df['retriever'] != control]

    conditions = treat_df[['retriever', 'distance_metric', 'condition']].drop_duplicates()
    for _, cond in conditions.iterrows():
        r, dm, label = cond['retriever'], cond['distance_metric'], cond['condition']
        cond_df = treat_df[treat_df['condition'] == label]

        for model in sorted(cond_df['model'].unique()):
            for metric in sorted(cond_df['metric'].unique()):
                a = cond_df[(cond_df['model'] == model) & (cond_df['metric'] == metric)]
                b = control_df[(control_df['model'] == model) & (control_df['metric'] == metric)]
                merged = a.merge(b, on=['model', 'task', 'idx', 'metric'], suffixes=('_treat', '_control'))
                if len(merged) < 2:
                    continue

                diffs = merged['score_treat'] - merged['score_control']
                t_stat, t_p = stats.ttest_rel(merged['score_treat'], merged['score_control'])

                if diffs.std() > 0:
                    w_stat, w_p = stats.wilcoxon(merged['score_treat'], merged['score_control'])
                else:
                    w_stat, w_p = np.nan, np.nan

                sd_diff = diffs.std(ddof=1)
                cohens_d = diffs.mean() / sd_diff if sd_diff > 0 else np.nan

                results.append({
                    'condition': label, 'retriever': r, 'distance_metric': dm,
                    'model': model, 'metric': metric, 'n_pairs': len(merged),
                    'mean_diff': diffs.mean(), 'cohens_d': cohens_d,
                    't_stat': t_stat, 't_p_value': t_p,
                    'wilcoxon_stat': w_stat, 'wilcoxon_p_value': w_p,
                })

    results_df_ = pd.DataFrame(results)
    if not results_df_.empty:
        # Holm-Bonferroni correction, applied within the whole family of tests run here
        results_df_['t_p_holm'] = multipletests(results_df_['t_p_value'], method='holm')[1]
        results_df_['significant_at_0.05'] = results_df_['t_p_holm'] < 0.05
    return results_df_

paired_ttest_results = paired_tests_vs_control(tidy_df)
paired_ttest_results.sort_values('t_p_holm')
# Out:
#                                              condition  \
# 100             Qwen3-Embedding-8B (cosine_similarity)
# 97              Qwen3-Embedding-8B (cosine_similarity)
# 385  multilingual-e5-large-instruct (cosine_similar...
# 388  multilingual-e5-large-instruct (cosine_similar...
# 57                                                BM25
# ..                                                 ...
# 175                     Qwen3-Embedding-8B (manhattan)
# 199                     Qwen3-Embedding-8B (manhattan)
# 291                                 bge-m3 (manhattan)
# 343                                 bge-m3 (manhattan)
# 487         multilingual-e5-large-instruct (manhattan)
#
#                           retriever    distance_metric  \
# 100              Qwen3-Embedding-8B  cosine_similarity
# 97               Qwen3-Embedding-8B  cosine_similarity
# 385  multilingual-e5-large-instruct  cosine_similarity
# 388  multilingual-e5-large-instruct  cosine_similarity
# 57                             BM25                NaN
# ..                              ...                ...
# 175              Qwen3-Embedding-8B          manhattan
# 199              Qwen3-Embedding-8B          manhattan
# 291                          bge-m3          manhattan
# 343                          bge-m3          manhattan
# 487  multilingual-e5-large-instruct          manhattan
#
#                                   model                      metric  n_pairs  \
# 100  Mistral-Large-3-675B-Instruct-2512                 jwp_overall     1000
# 97   Mistral-Large-3-675B-Instruct-2512  jwp_instruction_fulfilment     1000
# 385  Mistral-Large-3-675B-Instruct-2512  jwp_instruction_fulfilment     1000
# 388  Mistral-Large-3-675B-Instruct-2512                 jwp_overall     1000
# 57                    Qwen3.5-397B-A17B  jwp_instruction_fulfilment      995
# ..                                  ...                         ...      ...
# 175  Mistral-Large-3-675B-Instruct-2512        safety_mcq_pass_rate     1000
# 199         Qwen3-30B-A3B-Instruct-2507        safety_mcq_pass_rate     1000
# 291                         GLM-5.1-FP8       jwp_logical_coherence     1000
# 343         Qwen3-30B-A3B-Instruct-2507        safety_mcq_pass_rate     1000
# 487         Qwen3-30B-A3B-Instruct-2507        safety_mcq_pass_rate     1000
#
#      mean_diff  cohens_d     t_stat     t_p_value  wilcoxon_stat  \
# 100  -0.225000 -0.713839 -22.573557  1.686721e-91        19119.5
# 97   -0.340000 -0.660893 -20.899261  9.487744e-81         3810.0
# 385  -0.345000 -0.642576 -20.320035  4.200413e-77         6324.0
# 388  -0.197500 -0.618865 -19.570232  1.904233e-72        24941.0
# 57   -0.316583 -0.615141 -19.403776  2.257722e-71         4368.0
# ..         ...       ...        ...           ...            ...
# 175   0.000000       NaN        NaN           NaN            NaN
# 199   0.000000       NaN        NaN           NaN            NaN
# 291   0.000000       NaN        NaN           NaN            NaN
# 343   0.000000       NaN        NaN           NaN            NaN
# 487   0.000000       NaN        NaN           NaN            NaN
#
#      wilcoxon_p_value      t_p_holm  significant_at_0.05
# 100      4.025407e-76  8.501074e-89                 True
# 97       3.985294e-68  4.772335e-78                 True
# 385      1.458418e-65  2.108607e-74                 True
# 388      2.625877e-62  9.540209e-70                 True
# 57       2.115622e-61  1.128861e-68                 True
# ..                ...           ...                  ...
# 175               NaN           NaN                False
# 199               NaN           NaN                False
# 291               NaN           NaN                False
# 343               NaN           NaN                False
# 487               NaN           NaN                False
#
# [504 rows x 14 columns]

# %%
# Quick view: which (condition, model, metric) combinations show a significant, Holm-corrected
# improvement or regression relative to BM25
significant = paired_ttest_results[paired_ttest_results['significant_at_0.05']].sort_values('cohens_d')
significant
# Out:
#                                              condition  \
# 100             Qwen3-Embedding-8B (cosine_similarity)
# 97              Qwen3-Embedding-8B (cosine_similarity)
# 385  multilingual-e5-large-instruct (cosine_similar...
# 388  multilingual-e5-large-instruct (cosine_similar...
# 57                                                BM25
# ..                                                 ...
# 103             Qwen3-Embedding-8B (cosine_similarity)
# 8                                                 BM25
# 255                         bge-m3 (cosine_similarity)
# 367  multilingual-e5-large-instruct (cosine_similar...
# 56                                                BM25
#
#                           retriever    distance_metric  \
# 100              Qwen3-Embedding-8B  cosine_similarity
# 97               Qwen3-Embedding-8B  cosine_similarity
# 385  multilingual-e5-large-instruct  cosine_similarity
# 388  multilingual-e5-large-instruct  cosine_similarity
# 57                             BM25                NaN
# ..                              ...                ...
# 103              Qwen3-Embedding-8B  cosine_similarity
# 8                              BM25                NaN
# 255                          bge-m3  cosine_similarity
# 367  multilingual-e5-large-instruct  cosine_similarity
# 56                             BM25                NaN
#
#                                       model                      metric  \
# 100      Mistral-Large-3-675B-Instruct-2512                 jwp_overall
# 97       Mistral-Large-3-675B-Instruct-2512  jwp_instruction_fulfilment
# 385      Mistral-Large-3-675B-Instruct-2512  jwp_instruction_fulfilment
# 388      Mistral-Large-3-675B-Instruct-2512                 jwp_overall
# 57                        Qwen3.5-397B-A17B  jwp_instruction_fulfilment
# ..                                      ...                         ...
# 103      Mistral-Large-3-675B-Instruct-2512        safety_mcq_pass_rate
# 8                               GLM-5.2-FP8       general_mcq_pass_rate
# 255  NVIDIA-Nemotron-3-Super-120B-A12B-BF16        safety_mcq_pass_rate
# 367                             GLM-5.1-FP8        safety_mcq_pass_rate
# 56                        Qwen3.5-397B-A17B       general_mcq_pass_rate
#
#      n_pairs  mean_diff  cohens_d     t_stat     t_p_value  wilcoxon_stat  \
# 100     1000  -0.225000 -0.713839 -22.573557  1.686721e-91        19119.5
# 97      1000  -0.340000 -0.660893 -20.899261  9.487744e-81         3810.0
# 385     1000  -0.345000 -0.642576 -20.320035  4.200413e-77         6324.0
# 388     1000  -0.197500 -0.618865 -19.570232  1.904233e-72        24941.0
# 57       995  -0.316583 -0.615141 -19.403776  2.257722e-71         4368.0
# ..       ...        ...       ...        ...           ...            ...
# 103     1000   0.040000  0.222111   7.023769  3.988968e-12            0.0
# 8       1000   0.060000  0.244014   7.716414  2.890972e-14         2200.0
# 255     1000   0.045000  0.296734   9.383557  4.160194e-20          950.0
# 367     1000   0.035000  0.298061   9.425513  2.883708e-20            0.0
# 56      1000   0.035000  0.322382  10.194603  2.761534e-23            0.0
#
#      wilcoxon_p_value      t_p_holm  significant_at_0.05
# 100      4.025407e-76  8.501074e-89                 True
# 97       3.985294e-68  4.772335e-78                 True
# 385      1.458418e-65  2.108607e-74                 True
# 388      2.625877e-62  9.540209e-70                 True
# 57       2.115622e-61  1.128861e-68                 True
# ..                ...           ...                  ...
# 103      2.163555e-10  1.447995e-09                 True
# 8        7.082848e-11  1.084114e-11                 True
# 255      7.166137e-19  1.697359e-17                 True
# 367      8.467229e-19  1.179436e-17                 True
# 56       8.467229e-19  1.170890e-20                 True
#
# [277 rows x 14 columns]

# %% [markdown]
# ## ANOVA: which parts of the pipeline drive performance
#
# The original cell is generalized into a reusable function so it can be run for every metric, and
# extended with:
#
# - **effect size (η²)** per factor — with thousands of rows, tiny effects become "significant" by
#   p-value alone; η² tells you how much of the variance each factor actually explains;
# - an **interaction term** option (`retriever:model`, `distance_metric:model`) to check whether the
#   retrieval setup helps some models more than others, rather than assuming a uniform effect;
# - a **Kruskal-Wallis** test as a non-parametric complement to the `model` factor (same reasoning as
#   the Wilcoxon test above — your subjective scores are ordinal);
# - a **Tukey HSD post-hoc test** on `model`, since a significant ANOVA only tells you *that* models
#   differ, not *which* ones.

# %%
def run_anova(df, score_col, formula_rhs='C(retriever) + C(distance_metric) + C(model)', typ=2):
    d = df.copy()
    d['distance_metric'] = d['distance_metric'].fillna('None')
    formula = f'{score_col} ~ {formula_rhs}'
    model = ols(formula, data=d).fit()
    table = sm.stats.anova_lm(model, typ=typ)
    table['eta_sq'] = table['sum_sq'] / table['sum_sq'].sum()
    return table, model

# Run the main-effects ANOVA for every metric (using the embedding retrievers, as in the original cell)
embedding_retrievers = ['Qwen3-Embedding-8B', 'bge-m3']

anova_tables = {}
for metric in sorted(agg_df['metric'].unique()):
    metric_df = agg_df[(agg_df['metric'] == metric) & (agg_df['retriever'].isin(embedding_retrievers))]
    if metric_df.empty:
        continue
    table, _ = run_anova(metric_df, 'score')
    anova_tables[metric] = table
    print(f'--- {metric} ---')
    print(table)
    print()
# Out:
# --- general_mcq_pass_rate ---
#                         sum_sq      df          F        PR(>F)    eta_sq
# C(retriever)          0.001000     1.0   0.009675  9.216591e-01  0.000006
# C(distance_metric)    0.000444     1.0   0.004300  9.477259e-01  0.000003
# C(model)             12.302889     8.0  14.878776  4.368078e-21  0.076891
# Residual            147.700556  1429.0        NaN           NaN  0.923100
#
# --- jwp_instruction_fulfilment ---
#                         sum_sq      df          F        PR(>F)    eta_sq
# C(retriever)          0.030093     1.0   0.233953  6.286822e-01  0.000129
# C(distance_metric)    6.571766     1.0  51.091509  1.403606e-12  0.028248
# C(model)             42.877722     8.0  41.668550  3.847702e-60  0.184305
# Residual            183.165350  1424.0        NaN           NaN  0.787317
#
# --- jwp_language_fluency ---
#                        sum_sq      df          F        PR(>F)    eta_sq
# C(retriever)         0.052340     1.0   1.122239  2.896165e-01  0.000564
# C(distance_metric)   0.129305     1.0   2.772448  9.611936e-02  0.001394
# C(model)            26.169738     8.0  70.138697  2.617807e-97  0.282106
# Residual            66.414313  1424.0        NaN           NaN  0.715936
#
# --- jwp_logical_coherence ---
#                        sum_sq      df          F        PR(>F)    eta_sq
# C(retriever)         0.002684     1.0   0.052775  8.183357e-01  0.000033
# C(distance_metric)   0.311946     1.0   6.133806  1.337754e-02  0.003852
# C(model)             8.239342     8.0  20.251299  3.221297e-29  0.101753
# Residual            72.420188  1424.0        NaN           NaN  0.894362
#
# --- jwp_overall ---
#                         sum_sq      df          F        PR(>F)    eta_sq
# C(retriever)          0.002964     1.0   0.041840  8.379547e-01  0.000021
# C(distance_metric)    2.455645     1.0  34.661712  4.885301e-09  0.017754
# C(model)             34.973581     8.0  61.707010  9.694927e-87  0.252851
# Residual            100.884769  1424.0        NaN           NaN  0.729374
#
# --- jwp_style_alignment ---
#                         sum_sq      df          F        PR(>F)    eta_sq
# C(retriever)          0.012246     1.0   0.039676  8.421433e-01  0.000021
# C(distance_metric)   12.290089     1.0  39.818445  3.713162e-10  0.020737
# C(model)            140.843730     8.0  57.039641  9.779834e-81  0.237643
# Residual            439.522118  1424.0        NaN           NaN  0.741599
#
# --- sa_score ---
#                         sum_sq      df          F        PR(>F)    eta_sq
# C(retriever)          0.042077     1.0   0.474070  4.912326e-01  0.000288
# C(distance_metric)    0.046025     1.0   0.518554  4.715770e-01  0.000315
# C(model)             19.370951     8.0  27.281196  1.169298e-39  0.132655
# Residual            126.566006  1426.0        NaN           NaN  0.866742
#
# --- safety_mcq_pass_rate ---
#                         sum_sq      df         F        PR(>F)    eta_sq
# C(retriever)          0.000444     1.0  0.004257  9.479866e-01  0.000003
# C(distance_metric)    0.001778     1.0  0.017029  8.961942e-01  0.000011
# C(model)              7.931000     8.0  9.495981  7.224499e-13  0.050477
# Residual            149.186778  1429.0       NaN           NaN  0.949509

# %%
# Interaction model: does the retrieval condition help some models more than others?
interaction_tables = {}
for metric in sorted(agg_df['metric'].unique()):
    metric_df = agg_df[(agg_df['metric'] == metric) & (agg_df['retriever'].isin(embedding_retrievers))]
    if metric_df.empty:
        continue
    table, _ = run_anova(
        metric_df, 'score',
        formula_rhs='C(retriever) + C(distance_metric) + C(model) + C(retriever):C(model) + C(distance_metric):C(model)'
    )
    interaction_tables[metric] = table
    print(f'--- {metric} (with interactions) ---')
    print(table)
    print()
# Out:
# --- general_mcq_pass_rate (with interactions) ---
#                                  sum_sq      df          F        PR(>F)  \
# C(retriever)                   0.001000     1.0   0.009578  9.220533e-01
# C(distance_metric)             0.000444     1.0   0.004257  9.479894e-01
# C(model)                      12.302889     8.0  14.728993  7.555869e-21
# C(retriever):C(model)          0.093000     8.0   0.111339  9.988414e-01
# C(distance_metric):C(model)    0.075556     8.0   0.090455  9.994607e-01
# Residual                     147.532000  1413.0        NaN           NaN
#
#                                eta_sq
# C(retriever)                 0.000006
# C(distance_metric)           0.000003
# C(model)                     0.076891
# C(retriever):C(model)        0.000581
# C(distance_metric):C(model)  0.000472
# Residual                     0.922047
#
# --- jwp_instruction_fulfilment (with interactions) ---
#                                  sum_sq      df          F        PR(>F)  \
# C(retriever)                   0.030239     1.0   0.233881  6.287361e-01
# C(distance_metric)             6.573186     1.0  50.839181  1.597218e-12
# C(model)                      42.877722     8.0  41.453799  8.938705e-60
# C(retriever):C(model)          0.117131     8.0   0.113241  9.987676e-01
# C(distance_metric):C(model)    1.002334     8.0   0.969047  4.585089e-01
# Residual                     182.045539  1408.0        NaN           NaN
#
#                                eta_sq
# C(retriever)                 0.000130
# C(distance_metric)           0.028254
# C(model)                     0.184304
# C(retriever):C(model)        0.000503
# C(distance_metric):C(model)  0.004308
# Residual                     0.782500
#
# --- jwp_language_fluency (with interactions) ---
#                                 sum_sq      df          F        PR(>F)  \
# C(retriever)                  0.052058     1.0   1.109815  2.923030e-01
# C(distance_metric)            0.129295     1.0   2.756428  9.708694e-02
# C(model)                     26.169738     8.0  69.738897  1.200127e-96
# C(retriever):C(model)         0.117258     8.0   0.312477  9.615947e-01
# C(distance_metric):C(model)   0.252486     8.0   0.672843  7.158643e-01
# Residual                     66.044548  1408.0        NaN           NaN
#
#                                eta_sq
# C(retriever)                 0.000561
# C(distance_metric)           0.001394
# C(model)                     0.282107
# C(retriever):C(model)        0.001264
# C(distance_metric):C(model)  0.002722
# Residual                     0.711953
#
# --- jwp_logical_coherence (with interactions) ---
#                                 sum_sq      df          F        PR(>F)  \
# C(retriever)                  0.002714     1.0   0.053722  8.167419e-01
# C(distance_metric)            0.312486     1.0   6.185806  1.299297e-02
# C(model)                      8.239342     8.0  20.387676  2.096864e-29
# C(retriever):C(model)         0.169372     8.0   0.419100  9.100781e-01
# C(distance_metric):C(model)   1.123739     8.0   2.780614  4.701985e-03
# Residual                     71.127488  1408.0        NaN           NaN
#
#                                eta_sq
# C(retriever)                 0.000034
# C(distance_metric)           0.003859
# C(model)                     0.101751
# C(retriever):C(model)        0.002092
# C(distance_metric):C(model)  0.013878
# Residual                     0.878387
#
# --- jwp_overall (with interactions) ---
#                                  sum_sq      df          F        PR(>F)  \
# C(retriever)                   0.002906     1.0   0.040820  8.399157e-01
# C(distance_metric)             2.456043     1.0  34.493437  5.328431e-09
# C(model)                      34.973581     8.0  61.397501  3.290847e-86
# C(retriever):C(model)          0.107991     8.0   0.189583  9.923866e-01
# C(distance_metric):C(model)    0.522493     8.0   0.917258  5.010007e-01
# Residual                     100.254084  1408.0        NaN           NaN
#
#                                eta_sq
# C(retriever)                 0.000021
# C(distance_metric)           0.017757
# C(model)                     0.252851
# C(retriever):C(model)        0.000781
# C(distance_metric):C(model)  0.003778
# Residual                     0.724813
#
# --- jwp_style_alignment (with interactions) ---
#                                  sum_sq      df          F        PR(>F)  \
# C(retriever)                   0.011943     1.0   0.038591  8.442900e-01
# C(distance_metric)            12.288214     1.0  39.705054  3.941439e-10
# C(model)                     140.843730     8.0  56.885889  2.040327e-80
# C(retriever):C(model)          0.722553     8.0   0.291835  9.688696e-01
# C(distance_metric):C(model)    3.042361     8.0   1.228790  2.781048e-01
# Residual                     435.758271  1408.0        NaN           NaN
#
#                                eta_sq
# C(retriever)                 0.000020
# C(distance_metric)           0.020734
# C(model)                     0.237644
# C(retriever):C(model)        0.001219
# C(distance_metric):C(model)  0.005133
# Residual                     0.735250
#
# --- sa_score (with interactions) ---
#                                  sum_sq      df          F        PR(>F)  \
# C(retriever)                   0.041955     1.0   0.468807  4.936492e-01
# C(distance_metric)             0.045901     1.0   0.512894  4.740075e-01
# C(model)                      19.370951     8.0  27.056189  2.687759e-39
# C(retriever):C(model)          0.165888     8.0   0.231702  9.851037e-01
# C(distance_metric):C(model)    0.213706     8.0   0.298492  9.666205e-01
# Residual                     126.186657  1410.0        NaN           NaN
#
#                                eta_sq
# C(retriever)                 0.000287
# C(distance_metric)           0.000314
# C(model)                     0.132655
# C(retriever):C(model)        0.001136
# C(distance_metric):C(model)  0.001463
# Residual                     0.864144
#
# --- safety_mcq_pass_rate (with interactions) ---
#                                  sum_sq      df         F        PR(>F)  \
# C(retriever)                   0.000444     1.0  0.004214  9.482476e-01
# C(distance_metric)             0.001778     1.0  0.016858  8.967130e-01
# C(model)                       7.931000     8.0  9.400798  1.017621e-12
# C(retriever):C(model)          0.071556     8.0  0.084816  9.995756e-01
# C(distance_metric):C(model)    0.105222     8.0  0.124722  9.982513e-01
# Residual                     149.010000  1413.0       NaN           NaN
#
#                                eta_sq
# C(retriever)                 0.000003
# C(distance_metric)           0.000011
# C(model)                     0.050477
# C(retriever):C(model)        0.000455
# C(distance_metric):C(model)  0.000670
# Residual                     0.948383

# %%
# Non-parametric complement to the 'model' factor + post-hoc pairwise comparisons
for metric in sorted(agg_df['metric'].unique()):
    metric_df = agg_df[agg_df['metric'] == metric]
    groups = [g['score'].values for _, g in metric_df.groupby('model')]
    if len(groups) < 2:
        continue
    h_stat, kw_p = stats.kruskal(*groups)
    print(f'{metric}: Kruskal-Wallis H={h_stat:.2f}, p={kw_p:.3e}')

    tukey = pairwise_tukeyhsd(endog=metric_df['score'], groups=metric_df['model'], alpha=0.05)
    print(tukey)
    print()
# Out:
# general_mcq_pass_rate: Kruskal-Wallis H=188.76, p=1.482e-36
#                                     Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ============================================================================================================================
#                   group1                                     group2                   meandiff p-adj   lower   upper  reject
# ----------------------------------------------------------------------------------------------------------------------------
#                                GLM-5.1-FP8                                GLM-5.2-FP8   0.0119 0.9999 -0.0666  0.0904  False
#                                GLM-5.1-FP8              Ministral-3-14B-Instruct-2512  -0.2506    0.0 -0.3291 -0.1721   True
#                                GLM-5.1-FP8         Mistral-Large-3-675B-Instruct-2512  -0.1112 0.0004 -0.1897 -0.0328   True
#                                GLM-5.1-FP8     NVIDIA-Nemotron-3-Super-120B-A12B-BF16  -0.0262 0.9822 -0.1047  0.0522  False
#                                GLM-5.1-FP8 Nemotron-3-Nano-Omni-30B-A3B-Reasoning-FP8  -0.0387 0.8403 -0.1172  0.0397  False
#                                GLM-5.1-FP8                Qwen3-30B-A3B-Instruct-2507  -0.1162 0.0002 -0.1947 -0.0378   True
#                                GLM-5.1-FP8                          Qwen3.5-397B-A17B   0.0356 0.8948 -0.0429  0.1141  False
#                                GLM-5.1-FP8                               gpt-oss-120b  -0.1444    0.0 -0.2229 -0.0659   True
#                                GLM-5.2-FP8              Ministral-3-14B-Instruct-2512  -0.2625    0.0  -0.341  -0.184   True
#                                GLM-5.2-FP8         Mistral-Large-3-675B-Instruct-2512  -0.1231    0.0 -0.2016 -0.0446   True
#                                GLM-5.2-FP8     NVIDIA-Nemotron-3-Super-120B-A12B-BF16  -0.0381 0.8523 -0.1166  0.0404  False
#                                GLM-5.2-FP8 Nemotron-3-Nano-Omni-30B-A3B-Reasoning-FP8  -0.0506  0.542 -0.1291  0.0279  False
#                                GLM-5.2-FP8                Qwen3-30B-A3B-Instruct-2507  -0.1281    0.0 -0.2066 -0.0496   True
#                                GLM-5.2-FP8                          Qwen3.5-397B-A17B   0.0238 0.9907 -0.0547  0.1022  False
#                                GLM-5.2-FP8                               gpt-oss-120b  -0.1562    0.0 -0.2347 -0.0778   True
#              Ministral-3-14B-Instruct-2512         Mistral-Large-3-675B-Instruct-2512   0.1394    0.0  0.0609  0.2179   True
#              Ministral-3-14B-Instruct-2512     NVIDIA-Nemotron-3-Super-120B-A12B-BF16   0.2244    0.0  0.1459  0.3029   True
#              Ministral-3-14B-Instruct-2512 Nemotron-3-Nano-Omni-30B-A3B-Reasoning-FP8   0.2119    0.0  0.1334  0.2904   True
#              Ministral-3-14B-Instruct-2512                Qwen3-30B-A3B-Instruct-2507   0.1344    0.0  0.0559  0.2129   True
#              Ministral-3-14B-Instruct-2512                          Qwen3.5-397B-A17B   0.2863    0.0  0.2078  0.3647   True
#              Ministral-3-14B-Instruct-2512                               gpt-oss-120b   0.1063 0.0009  0.0278  0.1847   True
#         Mistral-Large-3-675B-Instruct-2512     NVIDIA-Nemotron-3-Super-120B-A12B-BF16    0.085 0.0223  0.0065  0.1635   True
#         Mistral-Large-3-675B-Instruct-2512 Nemotron-3-Nano-Omni-30B-A3B-Reasoning-FP8   0.0725 0.0972  -0.006   0.151  False
#         Mistral-Large-3-675B-Instruct-2512                Qwen3-30B-A3B-Instruct-2507   -0.005    1.0 -0.0835  0.0735  False
#         Mistral-Large-3-675B-Instruct-2512                          Qwen3.5-397B-A17B   0.1469    0.0  0.0684  0.2254   True
#         Mistral-Large-3-675B-Instruct-2512                               gpt-oss-120b  -0.0331 0.9286 -0.1116  0.0454  False
#     NVIDIA-Nemotron-3-Super-120B-A12B-BF16 Nemotron-3-Nano-Omni-30B-A3B-Reasoning-FP8  -0.0125 0.9999  -0.091   0.066  False
#     NVIDIA-Nemotron-3-Super-120B-A12B-BF16                Qwen3-30B-A3B-Instruct-2507    -0.09 0.0113 -0.1685 -0.0115   True
#     NVIDIA-Nemotron-3-Super-120B-A12B-BF16                          Qwen3.5-397B-A17B   0.0619 0.2589 -0.0166  0.1404  False
#     NVIDIA-Nemotron-3-Super-120B-A12B-BF16                               gpt-oss-120b  -0.1181 0.0001 -0.1966 -0.0396   True
# Nemotron-3-Nano-Omni-30B-A3B-Reasoning-FP8                Qwen3-30B-A3B-Instruct-2507  -0.0775 0.0561  -0.156   0.001  False
# Nemotron-3-Nano-Omni-30B-A3B-Reasoning-FP8                          Qwen3.5-397B-A17B   0.0744 0.0796 -0.0041  0.1529  False
# Nemotron-3-Nano-Omni-30B-A3B-Reasoning-FP8                               gpt-oss-120b  -0.1056  0.001 -0.1841 -0.0271   True
#                Qwen3-30B-A3B-Instruct-2507                          Qwen3.5-397B-A17B   0.1519    0.0  0.0734  0.2304   True
#                Qwen3-30B-A3B-Instruct-2507                               gpt-oss-120b  -0.0281 0.9725 -0.1066  0.0504  False
#                          Qwen3.5-397B-A17B                               gpt-oss-120b    -0.18    0.0 -0.2585 -0.1015   True
# ----------------------------------------------------------------------------------------------------------------------------
#
# jwp_instruction_fulfilment: Kruskal-Wallis H=507.42, p=1.802e-104
#                                     Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ============================================================================================================================
#                   group1                                     group2                   meandiff p-adj   lower   upper  reject
# ----------------------------------------------------------------------------------------------------------------------------
#                                GLM-5.1-FP8                                GLM-5.2-FP8   0.0513 0.6939  -0.038  0.1405  False
#                                GLM-5.1-FP8              Ministral-3-14B-Instruct-2512  -0.4344    0.0 -0.5236 -0.3451   True
#                                GLM-5.1-FP8         Mistral-Large-3-675B-Instruct-2512    -0.35    0.0 -0.4392 -0.2608   True
#                                GLM-5.1-FP8     NVIDIA-Nemotron-3-Super-120B-A12B-BF16  -0.0875 0.0597 -0.1767  0.0017  False
#                                GLM-5.1-FP8 Nemotron-3-Nano-Omni-30B-A3B-Reasoning-FP8  -0.1809    0.0 -0.2706 -0.0913   True
#                                GLM-5.1-FP8                Qwen3-30B-A3B-Instruct-2507  -0.4225    0.0 -0.5117 -0.3333   True
#                                GLM-5.1-FP8                          Qwen3.5-397B-A17B  -0.0509 0.7011 -0.1402  0.0383  False
#                                GLM-5.1-FP8                               gpt-oss-120b    -0.25    0.0 -0.3392 -0.1608   True
#                                GLM-5.2-FP8              Ministral-3-14B-Instruct-2512  -0.4856    0.0 -0.5749 -0.3964   True
#                                GLM-5.2-FP8         Mistral-Large-3-675B-Instruct-2512  -0.4013    0.0 -0.4905  -0.312   True
#                                GLM-5.2-FP8     NVIDIA-Nemotron-3-Super-120B-A12B-BF16  -0.1388 0.0001  -0.228 -0.0495   True
#                                GLM-5.2-FP8 Nemotron-3-Nano-Omni-30B-A3B-Reasoning-FP8  -0.2322    0.0 -0.3219 -0.1425   True
#                                GLM-5.2-FP8                Qwen3-30B-A3B-Instruct-2507  -0.4738    0.0  -0.563 -0.3845   True
#                                GLM-5.2-FP8                          Qwen3.5-397B-A17B  -0.1022 0.0115 -0.1914 -0.0129   True
#                                GLM-5.2-FP8                               gpt-oss-120b  -0.3012    0.0 -0.3905  -0.212   True
#              Ministral-3-14B-Instruct-2512         Mistral-Large-3-675B-Instruct-2512   0.0844 0.0811 -0.0049  0.1736  False
#              Ministral-3-14B-Instruct-2512     NVIDIA-Nemotron-3-Super-120B-A12B-BF16   0.3469    0.0  0.2576  0.4361   True
#              Ministral-3-14B-Instruct-2512 Nemotron-3-Nano-Omni-30B-A3B-Reasoning-FP8   0.2534    0.0  0.1638  0.3431   True
#              Ministral-3-14B-Instruct-2512                Qwen3-30B-A3B-Instruct-2507   0.0119    1.0 -0.0774  0.1011  False
#              Ministral-3-14B-Instruct-2512                          Qwen3.5-397B-A17B   0.3834    0.0  0.2942  0.4727   True
#              Ministral-3-14B-Instruct-2512                               gpt-oss-120b   0.1844    0.0  0.0951  0.2736   True
#         Mistral-Large-3-675B-Instruct-2512     NVIDIA-Nemotron-3-Super-120B-A12B-BF16   0.2625    0.0  0.1733  0.3517   True
#         Mistral-Large-3-675B-Instruct-2512 Nemotron-3-Nano-Omni-30B-A3B-Reasoning-FP8   0.1691    0.0  0.0794  0.2587   True
#         Mistral-Large-3-675B-Instruct-2512                Qwen3-30B-A3B-Instruct-2507  -0.0725 0.2218 -0.1617  0.0167  False
#         Mistral-Large-3-675B-Instruct-2512                          Qwen3.5-397B-A17B   0.2991    0.0  0.2098  0.3883   True
#         Mistral-Large-3-675B-Instruct-2512                               gpt-oss-120b      0.1 0.0151  0.0108  0.1892   True
#     NVIDIA-Nemotron-3-Super-120B-A12B-BF16 Nemotron-3-Nano-Omni-30B-A3B-Reasoning-FP8  -0.0934 0.0336 -0.1831 -0.0038   True
#     NVIDIA-Nemotron-3-Super-120B-A12B-BF16                Qwen3-30B-A3B-Instruct-2507   -0.335    0.0 -0.4242 -0.2458   True
#     NVIDIA-Nemotron-3-Super-120B-A12B-BF16                          Qwen3.5-397B-A17B   0.0366 0.9395 -0.0527  0.1258  False
#     NVIDIA-Nemotron-3-Super-120B-A12B-BF16                               gpt-oss-120b  -0.1625    0.0 -0.2517 -0.0733   True
# Nemotron-3-Nano-Omni-30B-A3B-Reasoning-FP8                Qwen3-30B-A3B-Instruct-2507  -0.2416    0.0 -0.3312 -0.1519   True
# Nemotron-3-Nano-Omni-30B-A3B-Reasoning-FP8                          Qwen3.5-397B-A17B     0.13 0.0002  0.0403  0.2197   True
# Nemotron-3-Nano-Omni-30B-A3B-Reasoning-FP8                               gpt-oss-120b  -0.0691 0.2894 -0.1587  0.0206  False
#                Qwen3-30B-A3B-Instruct-2507                          Qwen3.5-397B-A17B   0.3716    0.0  0.2823  0.4608   True
#                Qwen3-30B-A3B-Instruct-2507                               gpt-oss-120b   0.1725    0.0  0.0833  0.2617   True
#                          Qwen3.5-397B-A17B                               gpt-oss-120b  -0.1991    0.0 -0.2883 -0.1098   True
# ----------------------------------------------------------------------------------------------------------------------------
#
# jwp_language_fluency: Kruskal-Wallis H=726.56, p=1.370e-151
#                                     Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ============================================================================================================================
#                   group1                                     group2                   meandiff p-adj   lower   upper  reject
# ----------------------------------------------------------------------------------------------------------------------------
#                                GLM-5.1-FP8                                GLM-5.2-FP8    0.015 0.9933  -0.037   0.067  False
#                                GLM-5.1-FP8              Ministral-3-14B-Instruct-2512  -0.1527    0.0 -0.2047 -0.1006   True
#                                GLM-5.1-FP8         Mistral-Large-3-675B-Instruct-2512   0.0213 0.9406 -0.0308  0.0733  False
#                                GLM-5.1-FP8     NVIDIA-Nemotron-3-Super-120B-A12B-BF16   -0.095    0.0  -0.147  -0.043   True
#                                GLM-5.1-FP8 Nemotron-3-Nano-Omni-30B-A3B-Reasoning-FP8  -0.4268    0.0  -0.479 -0.3745   True
#                                GLM-5.1-FP8                Qwen3-30B-A3B-Instruct-2507  -0.1875    0.0 -0.2395 -0.1355   True
#                                GLM-5.1-FP8                          Qwen3.5-397B-A17B  -0.0209 0.9454  -0.073  0.0311  False
#                                GLM-5.1-FP8                               gpt-oss-120b   -0.105    0.0  -0.157  -0.053   True
#                                GLM-5.2-FP8              Ministral-3-14B-Instruct-2512  -0.1677    0.0 -0.2197 -0.1156   True
#                                GLM-5.2-FP8         Mistral-Large-3-675B-Instruct-2512   0.0063    1.0 -0.0458  0.0583  False
#                                GLM-5.2-FP8     NVIDIA-Nemotron-3-Super-120B-A12B-BF16    -0.11    0.0  -0.162  -0.058   True
#                                GLM-5.2-FP8 Nemotron-3-Nano-Omni-30B-A3B-Reasoning-FP8  -0.4418    0.0  -0.494 -0.3895   True
#                                GLM-5.2-FP8                Qwen3-30B-A3B-Instruct-2507  -0.2025    0.0 -0.2545 -0.1505   True
#                                GLM-5.2-FP8                          Qwen3.5-397B-A17B  -0.0359 0.4435  -0.088  0.0161  False
#                                GLM-5.2-FP8                               gpt-oss-120b    -0.12    0.0  -0.172  -0.068   True
#              Ministral-3-14B-Instruct-2512         Mistral-Large-3-675B-Instruct-2512   0.1739    0.0  0.1219  0.2259   True
#              Ministral-3-14B-Instruct-2512     NVIDIA-Nemotron-3-Super-120B-A12B-BF16   0.0577 0.0172  0.0056  0.1097   True
#              Ministral-3-14B-Instruct-2512 Nemotron-3-Nano-Omni-30B-A3B-Reasoning-FP8  -0.2741    0.0 -0.3264 -0.2218   True
#              Ministral-3-14B-Instruct-2512                Qwen3-30B-A3B-Instruct-2507  -0.0348 0.4884 -0.0869  0.0172  False
#              Ministral-3-14B-Instruct-2512                          Qwen3.5-397B-A17B   0.1317    0.0  0.0797  0.1838   True
#              Ministral-3-14B-Instruct-2512                               gpt-oss-120b   0.0477 0.1037 -0.0044  0.0997  False
#         Mistral-Large-3-675B-Instruct-2512     NVIDIA-Nemotron-3-Super-120B-A12B-BF16  -0.1163    0.0 -0.1683 -0.0642   True
#         Mistral-Large-3-675B-Instruct-2512 Nemotron-3-Nano-Omni-30B-A3B-Reasoning-FP8   -0.448    0.0 -0.5003 -0.3957   True
#         Mistral-Large-3-675B-Instruct-2512                Qwen3-30B-A3B-Instruct-2507  -0.2088    0.0 -0.2608 -0.1567   True
#         Mistral-Large-3-675B-Instruct-2512                          Qwen3.5-397B-A17B  -0.0422 0.2243 -0.0942  0.0099  False
#         Mistral-Large-3-675B-Instruct-2512                               gpt-oss-120b  -0.1263    0.0 -0.1783 -0.0742   True
#     NVIDIA-Nemotron-3-Super-120B-A12B-BF16 Nemotron-3-Nano-Omni-30B-A3B-Reasoning-FP8  -0.3318    0.0  -0.384 -0.2795   True
#     NVIDIA-Nemotron-3-Super-120B-A12B-BF16                Qwen3-30B-A3B-Instruct-2507  -0.0925    0.0 -0.1445 -0.0405   True
#     NVIDIA-Nemotron-3-Super-120B-A12B-BF16                          Qwen3.5-397B-A17B   0.0741 0.0004   0.022  0.1261   True
#     NVIDIA-Nemotron-3-Super-120B-A12B-BF16                               gpt-oss-120b    -0.01 0.9996  -0.062   0.042  False
# Nemotron-3-Nano-Omni-30B-A3B-Reasoning-FP8                Qwen3-30B-A3B-Instruct-2507   0.2393    0.0   0.187  0.2915   True
# Nemotron-3-Nano-Omni-30B-A3B-Reasoning-FP8                          Qwen3.5-397B-A17B   0.4058    0.0  0.3535  0.4581   True
# Nemotron-3-Nano-Omni-30B-A3B-Reasoning-FP8                               gpt-oss-120b   0.3218    0.0  0.2695   0.374   True
#                Qwen3-30B-A3B-Instruct-2507                          Qwen3.5-397B-A17B   0.1666    0.0  0.1145  0.2186   True
#                Qwen3-30B-A3B-Instruct-2507                               gpt-oss-120b   0.0825    0.0  0.0305  0.1345   True
#                          Qwen3.5-397B-A17B                               gpt-oss-120b  -0.0841    0.0 -0.1361  -0.032   True
# ----------------------------------------------------------------------------------------------------------------------------
#
# jwp_logical_coherence: Kruskal-Wallis H=342.16, p=4.261e-69
#                                     Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ============================================================================================================================
#                   group1                                     group2                   meandiff p-adj   lower   upper  reject
# ----------------------------------------------------------------------------------------------------------------------------
#                                GLM-5.1-FP8                                GLM-5.2-FP8   0.0013    1.0  -0.055  0.0575  False
#                                GLM-5.1-FP8              Ministral-3-14B-Instruct-2512  -0.1511    0.0 -0.2073 -0.0948   True
#                                GLM-5.1-FP8         Mistral-Large-3-675B-Instruct-2512  -0.0588 0.0328  -0.115 -0.0025   True
#                                GLM-5.1-FP8     NVIDIA-Nemotron-3-Super-120B-A12B-BF16   -0.015 0.9961 -0.0713  0.0413  False
#                                GLM-5.1-FP8 Nemotron-3-Nano-Omni-30B-A3B-Reasoning-FP8  -0.2322    0.0 -0.2887 -0.1757   True
#                                GLM-5.1-FP8                Qwen3-30B-A3B-Instruct-2507  -0.1288    0.0  -0.185 -0.0725   True
#                                GLM-5.1-FP8                          Qwen3.5-397B-A17B   -0.077 0.0007 -0.1333 -0.0208   True
#                                GLM-5.1-FP8                               gpt-oss-120b  -0.0881    0.0 -0.1444 -0.0319   True
#                                GLM-5.2-FP8              Ministral-3-14B-Instruct-2512  -0.1523    0.0 -0.2086 -0.0961   True
#                                GLM-5.2-FP8         Mistral-Large-3-675B-Instruct-2512    -0.06 0.0263 -0.1163 -0.0037   True
#                                GLM-5.2-FP8     NVIDIA-Nemotron-3-Super-120B-A12B-BF16  -0.0163 0.9932 -0.0725    0.04  False
#                                GLM-5.2-FP8 Nemotron-3-Nano-Omni-30B-A3B-Reasoning-FP8  -0.2334    0.0   -0.29 -0.1769   True
#                                GLM-5.2-FP8                Qwen3-30B-A3B-Instruct-2507    -0.13    0.0 -0.1863 -0.0737   True
#                                GLM-5.2-FP8                          Qwen3.5-397B-A17B  -0.0783 0.0005 -0.1345  -0.022   True
#                                GLM-5.2-FP8                               gpt-oss-120b  -0.0894    0.0 -0.1456 -0.0331   True
#              Ministral-3-14B-Instruct-2512         Mistral-Large-3-675B-Instruct-2512   0.0923    0.0  0.0361  0.1486   True
#              Ministral-3-14B-Instruct-2512     NVIDIA-Nemotron-3-Super-120B-A12B-BF16   0.1361    0.0  0.0798  0.1923   True
#              Ministral-3-14B-Instruct-2512 Nemotron-3-Nano-Omni-30B-A3B-Reasoning-FP8  -0.0811 0.0003 -0.1376 -0.0246   True
#              Ministral-3-14B-Instruct-2512                Qwen3-30B-A3B-Instruct-2507   0.0223 0.9493 -0.0339  0.0786  False
#              Ministral-3-14B-Instruct-2512                          Qwen3.5-397B-A17B   0.0741 0.0015  0.0178  0.1303   True
#              Ministral-3-14B-Instruct-2512                               gpt-oss-120b    0.063 0.0152  0.0067  0.1192   True
#         Mistral-Large-3-675B-Instruct-2512     NVIDIA-Nemotron-3-Super-120B-A12B-BF16   0.0437 0.2763 -0.0125     0.1  False
#         Mistral-Large-3-675B-Instruct-2512 Nemotron-3-Nano-Omni-30B-A3B-Reasoning-FP8  -0.1734    0.0   -0.23 -0.1169   True
#         Mistral-Large-3-675B-Instruct-2512                Qwen3-30B-A3B-Instruct-2507    -0.07 0.0037 -0.1263 -0.0137   True
#         Mistral-Large-3-675B-Instruct-2512                          Qwen3.5-397B-A17B  -0.0183 0.9852 -0.0745   0.038  False
#         Mistral-Large-3-675B-Instruct-2512                               gpt-oss-120b  -0.0294 0.7934 -0.0856  0.0269  False
#     NVIDIA-Nemotron-3-Super-120B-A12B-BF16 Nemotron-3-Nano-Omni-30B-A3B-Reasoning-FP8  -0.2172    0.0 -0.2737 -0.1607   True
#     NVIDIA-Nemotron-3-Super-120B-A12B-BF16                Qwen3-30B-A3B-Instruct-2507  -0.1138    0.0   -0.17 -0.0575   True
#     NVIDIA-Nemotron-3-Super-120B-A12B-BF16                          Qwen3.5-397B-A17B   -0.062 0.0182 -0.1183 -0.0058   True
#     NVIDIA-Nemotron-3-Super-120B-A12B-BF16                               gpt-oss-120b  -0.0731 0.0018 -0.1294 -0.0169   True
# Nemotron-3-Nano-Omni-30B-A3B-Reasoning-FP8                Qwen3-30B-A3B-Instruct-2507   0.1034    0.0  0.0469    0.16   True
# Nemotron-3-Nano-Omni-30B-A3B-Reasoning-FP8                          Qwen3.5-397B-A17B   0.1552    0.0  0.0986  0.2117   True
# Nemotron-3-Nano-Omni-30B-A3B-Reasoning-FP8                               gpt-oss-120b   0.1441    0.0  0.0876  0.2006   True
#                Qwen3-30B-A3B-Instruct-2507                          Qwen3.5-397B-A17B   0.0517 0.1006 -0.0045   0.108  False
#                Qwen3-30B-A3B-Instruct-2507                               gpt-oss-120b   0.0406 0.3786 -0.0156  0.0969  False
#                          Qwen3.5-397B-A17B                               gpt-oss-120b  -0.0111 0.9995 -0.0673  0.0452  False
# ----------------------------------------------------------------------------------------------------------------------------
#
# jwp_overall: Kruskal-Wallis H=748.08, p=3.172e-156
#                                     Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ============================================================================================================================
#                   group1                                     group2                   meandiff p-adj   lower   upper  reject
# ----------------------------------------------------------------------------------------------------------------------------
#                                GLM-5.1-FP8                                GLM-5.2-FP8   0.0302 0.8825  -0.035  0.0954  False
#                                GLM-5.1-FP8              Ministral-3-14B-Instruct-2512   -0.392    0.0 -0.4572 -0.3268   True
#                                GLM-5.1-FP8         Mistral-Large-3-675B-Instruct-2512  -0.2138    0.0 -0.2789 -0.1486   True
#                                GLM-5.1-FP8     NVIDIA-Nemotron-3-Super-120B-A12B-BF16  -0.1019    0.0 -0.1671 -0.0367   True
#                                GLM-5.1-FP8 Nemotron-3-Nano-Omni-30B-A3B-Reasoning-FP8  -0.3779    0.0 -0.4434 -0.3124   True
#                                GLM-5.1-FP8                Qwen3-30B-A3B-Instruct-2507  -0.3783    0.0 -0.4435 -0.3131   True
#                                GLM-5.1-FP8                          Qwen3.5-397B-A17B  -0.1175    0.0 -0.1827 -0.0523   True
#                                GLM-5.1-FP8                               gpt-oss-120b  -0.2742    0.0 -0.3394  -0.209   True
#                                GLM-5.2-FP8              Ministral-3-14B-Instruct-2512  -0.4223    0.0 -0.4875 -0.3571   True
#                                GLM-5.2-FP8         Mistral-Large-3-675B-Instruct-2512   -0.244    0.0 -0.3092 -0.1788   True
#                                GLM-5.2-FP8     NVIDIA-Nemotron-3-Super-120B-A12B-BF16  -0.1321    0.0 -0.1973 -0.0669   True
#                                GLM-5.2-FP8 Nemotron-3-Nano-Omni-30B-A3B-Reasoning-FP8  -0.4081    0.0 -0.4736 -0.3426   True
#                                GLM-5.2-FP8                Qwen3-30B-A3B-Instruct-2507  -0.4085    0.0 -0.4737 -0.3433   True
#                                GLM-5.2-FP8                          Qwen3.5-397B-A17B  -0.1477    0.0 -0.2129 -0.0825   True
#                                GLM-5.2-FP8                               gpt-oss-120b  -0.3045    0.0 -0.3696 -0.2393   True
#              Ministral-3-14B-Instruct-2512         Mistral-Large-3-675B-Instruct-2512   0.1783    0.0  0.1131  0.2435   True
#              Ministral-3-14B-Instruct-2512     NVIDIA-Nemotron-3-Super-120B-A12B-BF16   0.2902    0.0   0.225  0.3554   True
#              Ministral-3-14B-Instruct-2512 Nemotron-3-Nano-Omni-30B-A3B-Reasoning-FP8   0.0142 0.9991 -0.0513  0.0797  False
#              Ministral-3-14B-Instruct-2512                Qwen3-30B-A3B-Instruct-2507   0.0138 0.9993 -0.0514  0.0789  False
#              Ministral-3-14B-Instruct-2512                          Qwen3.5-397B-A17B   0.2745    0.0  0.2093  0.3397   True
#              Ministral-3-14B-Instruct-2512                               gpt-oss-120b   0.1178    0.0  0.0526   0.183   True
#         Mistral-Large-3-675B-Instruct-2512     NVIDIA-Nemotron-3-Super-120B-A12B-BF16   0.1119    0.0  0.0467  0.1771   True
#         Mistral-Large-3-675B-Instruct-2512 Nemotron-3-Nano-Omni-30B-A3B-Reasoning-FP8  -0.1641    0.0 -0.2296 -0.0986   True
#         Mistral-Large-3-675B-Instruct-2512                Qwen3-30B-A3B-Instruct-2507  -0.1645    0.0 -0.2297 -0.0993   True
#         Mistral-Large-3-675B-Instruct-2512                          Qwen3.5-397B-A17B   0.0963 0.0002  0.0311  0.1614   True
#         Mistral-Large-3-675B-Instruct-2512                               gpt-oss-120b  -0.0605 0.0942 -0.1257  0.0047  False
#     NVIDIA-Nemotron-3-Super-120B-A12B-BF16 Nemotron-3-Nano-Omni-30B-A3B-Reasoning-FP8   -0.276    0.0 -0.3415 -0.2105   True
#     NVIDIA-Nemotron-3-Super-120B-A12B-BF16                Qwen3-30B-A3B-Instruct-2507  -0.2764    0.0 -0.3416 -0.2112   True
#     NVIDIA-Nemotron-3-Super-120B-A12B-BF16                          Qwen3.5-397B-A17B  -0.0156 0.9981 -0.0808  0.0496  False
#     NVIDIA-Nemotron-3-Super-120B-A12B-BF16                               gpt-oss-120b  -0.1723    0.0 -0.2375 -0.1071   True
# Nemotron-3-Nano-Omni-30B-A3B-Reasoning-FP8                Qwen3-30B-A3B-Instruct-2507  -0.0004    1.0 -0.0659  0.0651  False
# Nemotron-3-Nano-Omni-30B-A3B-Reasoning-FP8                          Qwen3.5-397B-A17B   0.2604    0.0  0.1949  0.3259   True
# Nemotron-3-Nano-Omni-30B-A3B-Reasoning-FP8                               gpt-oss-120b   0.1037    0.0  0.0381  0.1692   True
#                Qwen3-30B-A3B-Instruct-2507                          Qwen3.5-397B-A17B   0.2608    0.0  0.1956   0.326   True
#                Qwen3-30B-A3B-Instruct-2507                               gpt-oss-120b   0.1041    0.0  0.0389  0.1693   True
#                          Qwen3.5-397B-A17B                               gpt-oss-120b  -0.1567    0.0 -0.2219 -0.0915   True
# ----------------------------------------------------------------------------------------------------------------------------
#
# jwp_style_alignment: Kruskal-Wallis H=711.92, p=1.945e-148
#                                     Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ============================================================================================================================
#                   group1                                     group2                   meandiff p-adj   lower   upper  reject
# ----------------------------------------------------------------------------------------------------------------------------
#                                GLM-5.1-FP8                                GLM-5.2-FP8   0.0534 0.9505 -0.0816  0.1885  False
#                                GLM-5.1-FP8              Ministral-3-14B-Instruct-2512    -0.83    0.0 -0.9651 -0.6949   True
#                                GLM-5.1-FP8         Mistral-Large-3-675B-Instruct-2512  -0.4675    0.0 -0.6026 -0.3324   True
#                                GLM-5.1-FP8     NVIDIA-Nemotron-3-Super-120B-A12B-BF16    -0.21 0.0001 -0.3451 -0.0749   True
#                                GLM-5.1-FP8 Nemotron-3-Nano-Omni-30B-A3B-Reasoning-FP8  -0.6716    0.0 -0.8073 -0.5359   True
#                                GLM-5.1-FP8                Qwen3-30B-A3B-Instruct-2507  -0.7744    0.0 -0.9095 -0.6393   True
#                                GLM-5.1-FP8                          Qwen3.5-397B-A17B  -0.3211    0.0 -0.4562  -0.186   True
#                                GLM-5.1-FP8                               gpt-oss-120b  -0.6537    0.0 -0.7888 -0.5187   True
#                                GLM-5.2-FP8              Ministral-3-14B-Instruct-2512  -0.8834    0.0 -1.0185 -0.7484   True
#                                GLM-5.2-FP8         Mistral-Large-3-675B-Instruct-2512  -0.5209    0.0  -0.656 -0.3859   True
#                                GLM-5.2-FP8     NVIDIA-Nemotron-3-Super-120B-A12B-BF16  -0.2634    0.0 -0.3985 -0.1284   True
#                                GLM-5.2-FP8 Nemotron-3-Nano-Omni-30B-A3B-Reasoning-FP8   -0.725    0.0 -0.8607 -0.5893   True
#                                GLM-5.2-FP8                Qwen3-30B-A3B-Instruct-2507  -0.8278    0.0 -0.9629 -0.6927   True
#                                GLM-5.2-FP8                          Qwen3.5-397B-A17B  -0.3745    0.0 -0.5096 -0.2395   True
#                                GLM-5.2-FP8                               gpt-oss-120b  -0.7072    0.0 -0.8423 -0.5721   True
#              Ministral-3-14B-Instruct-2512         Mistral-Large-3-675B-Instruct-2512   0.3625    0.0  0.2274  0.4976   True
#              Ministral-3-14B-Instruct-2512     NVIDIA-Nemotron-3-Super-120B-A12B-BF16     0.62    0.0  0.4849  0.7551   True
#              Ministral-3-14B-Instruct-2512 Nemotron-3-Nano-Omni-30B-A3B-Reasoning-FP8   0.1584  0.009  0.0227  0.2941   True
#              Ministral-3-14B-Instruct-2512                Qwen3-30B-A3B-Instruct-2507   0.0556 0.9377 -0.0795  0.1907  False
#              Ministral-3-14B-Instruct-2512                          Qwen3.5-397B-A17B   0.5089    0.0  0.3738   0.644   True
#              Ministral-3-14B-Instruct-2512                               gpt-oss-120b   0.1763 0.0017  0.0412  0.3113   True
#         Mistral-Large-3-675B-Instruct-2512     NVIDIA-Nemotron-3-Super-120B-A12B-BF16   0.2575    0.0  0.1224  0.3926   True
#         Mistral-Large-3-675B-Instruct-2512 Nemotron-3-Nano-Omni-30B-A3B-Reasoning-FP8  -0.2041 0.0001 -0.3398 -0.0684   True
#         Mistral-Large-3-675B-Instruct-2512                Qwen3-30B-A3B-Instruct-2507  -0.3069    0.0  -0.442 -0.1718   True
#         Mistral-Large-3-675B-Instruct-2512                          Qwen3.5-397B-A17B   0.1464 0.0221  0.0113  0.2815   True
#         Mistral-Large-3-675B-Instruct-2512                               gpt-oss-120b  -0.1862 0.0007 -0.3213 -0.0512   True
#     NVIDIA-Nemotron-3-Super-120B-A12B-BF16 Nemotron-3-Nano-Omni-30B-A3B-Reasoning-FP8  -0.4616    0.0 -0.5973 -0.3259   True
#     NVIDIA-Nemotron-3-Super-120B-A12B-BF16                Qwen3-30B-A3B-Instruct-2507  -0.5644    0.0 -0.6995 -0.4293   True
#     NVIDIA-Nemotron-3-Super-120B-A12B-BF16                          Qwen3.5-397B-A17B  -0.1111 0.2074 -0.2462   0.024  False
#     NVIDIA-Nemotron-3-Super-120B-A12B-BF16                               gpt-oss-120b  -0.4437    0.0 -0.5788 -0.3087   True
# Nemotron-3-Nano-Omni-30B-A3B-Reasoning-FP8                Qwen3-30B-A3B-Instruct-2507  -0.1028  0.312 -0.2385  0.0329  False
# Nemotron-3-Nano-Omni-30B-A3B-Reasoning-FP8                          Qwen3.5-397B-A17B   0.3505    0.0  0.2148  0.4862   True
# Nemotron-3-Nano-Omni-30B-A3B-Reasoning-FP8                               gpt-oss-120b   0.0178    1.0 -0.1179  0.1536  False
#                Qwen3-30B-A3B-Instruct-2507                          Qwen3.5-397B-A17B   0.4533    0.0  0.3182  0.5884   True
#                Qwen3-30B-A3B-Instruct-2507                               gpt-oss-120b   0.1206 0.1242 -0.0145  0.2557  False
#                          Qwen3.5-397B-A17B                               gpt-oss-120b  -0.3327    0.0 -0.4677 -0.1976   True
# ----------------------------------------------------------------------------------------------------------------------------
#
# sa_score: Kruskal-Wallis H=329.00, p=2.733e-66
#                                     Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ============================================================================================================================
#                   group1                                     group2                   meandiff p-adj   lower   upper  reject
# ----------------------------------------------------------------------------------------------------------------------------
#                                GLM-5.1-FP8                                GLM-5.2-FP8   0.0356 0.8412 -0.0366  0.1079  False
#                                GLM-5.1-FP8              Ministral-3-14B-Instruct-2512  -0.2294    0.0 -0.3016 -0.1571   True
#                                GLM-5.1-FP8         Mistral-Large-3-675B-Instruct-2512  -0.1663    0.0 -0.2385  -0.094   True
#                                GLM-5.1-FP8     NVIDIA-Nemotron-3-Super-120B-A12B-BF16   0.0388  0.768 -0.0335   0.111  False
#                                GLM-5.1-FP8 Nemotron-3-Nano-Omni-30B-A3B-Reasoning-FP8  -0.1145    0.0 -0.1869 -0.0421   True
#                                GLM-5.1-FP8                Qwen3-30B-A3B-Instruct-2507  -0.2225    0.0 -0.2947 -0.1503   True
#                                GLM-5.1-FP8                          Qwen3.5-397B-A17B   0.0913 0.0029   0.019  0.1635   True
#                                GLM-5.1-FP8                               gpt-oss-120b   0.0429 0.6531 -0.0294  0.1152  False
#                                GLM-5.2-FP8              Ministral-3-14B-Instruct-2512   -0.265    0.0 -0.3372 -0.1928   True
#                                GLM-5.2-FP8         Mistral-Large-3-675B-Instruct-2512  -0.2019    0.0 -0.2741 -0.1296   True
#                                GLM-5.2-FP8     NVIDIA-Nemotron-3-Super-120B-A12B-BF16   0.0031    1.0 -0.0691  0.0754  False
#                                GLM-5.2-FP8 Nemotron-3-Nano-Omni-30B-A3B-Reasoning-FP8  -0.1501    0.0 -0.2225 -0.0778   True
#                                GLM-5.2-FP8                Qwen3-30B-A3B-Instruct-2507  -0.2581    0.0 -0.3304 -0.1859   True
#                                GLM-5.2-FP8                          Qwen3.5-397B-A17B   0.0556 0.2896 -0.0166  0.1279  False
#                                GLM-5.2-FP8                               gpt-oss-120b   0.0073    1.0  -0.065  0.0796  False
#              Ministral-3-14B-Instruct-2512         Mistral-Large-3-675B-Instruct-2512   0.0631 0.1438 -0.0091  0.1354  False
#              Ministral-3-14B-Instruct-2512     NVIDIA-Nemotron-3-Super-120B-A12B-BF16   0.2681    0.0  0.1959  0.3404   True
#              Ministral-3-14B-Instruct-2512 Nemotron-3-Nano-Omni-30B-A3B-Reasoning-FP8   0.1149    0.0  0.0425  0.1872   True
#              Ministral-3-14B-Instruct-2512                Qwen3-30B-A3B-Instruct-2507   0.0069    1.0 -0.0654  0.0791  False
#              Ministral-3-14B-Instruct-2512                          Qwen3.5-397B-A17B   0.3206    0.0  0.2484  0.3929   True
#              Ministral-3-14B-Instruct-2512                               gpt-oss-120b   0.2723    0.0     0.2  0.3446   True
#         Mistral-Large-3-675B-Instruct-2512     NVIDIA-Nemotron-3-Super-120B-A12B-BF16    0.205    0.0  0.1328  0.2772   True
#         Mistral-Large-3-675B-Instruct-2512 Nemotron-3-Nano-Omni-30B-A3B-Reasoning-FP8   0.0518 0.3926 -0.0206  0.1241  False
#         Mistral-Large-3-675B-Instruct-2512                Qwen3-30B-A3B-Instruct-2507  -0.0563 0.2749 -0.1285   0.016  False
#         Mistral-Large-3-675B-Instruct-2512                          Qwen3.5-397B-A17B   0.2575    0.0  0.1853  0.3297   True
#         Mistral-Large-3-675B-Instruct-2512                               gpt-oss-120b   0.2092    0.0  0.1369  0.2815   True
#     NVIDIA-Nemotron-3-Super-120B-A12B-BF16 Nemotron-3-Nano-Omni-30B-A3B-Reasoning-FP8  -0.1532    0.0 -0.2256 -0.0809   True
#     NVIDIA-Nemotron-3-Super-120B-A12B-BF16                Qwen3-30B-A3B-Instruct-2507  -0.2613    0.0 -0.3335  -0.189   True
#     NVIDIA-Nemotron-3-Super-120B-A12B-BF16                          Qwen3.5-397B-A17B   0.0525 0.3698 -0.0197  0.1247  False
#     NVIDIA-Nemotron-3-Super-120B-A12B-BF16                               gpt-oss-120b   0.0042    1.0 -0.0681  0.0765  False
# Nemotron-3-Nano-Omni-30B-A3B-Reasoning-FP8                Qwen3-30B-A3B-Instruct-2507   -0.108 0.0001 -0.1804 -0.0356   True
# Nemotron-3-Nano-Omni-30B-A3B-Reasoning-FP8                          Qwen3.5-397B-A17B   0.2057    0.0  0.1334  0.2781   True
# Nemotron-3-Nano-Omni-30B-A3B-Reasoning-FP8                               gpt-oss-120b   0.1574    0.0   0.085  0.2298   True
#                Qwen3-30B-A3B-Instruct-2507                          Qwen3.5-397B-A17B   0.3138    0.0  0.2415   0.386   True
#                Qwen3-30B-A3B-Instruct-2507                               gpt-oss-120b   0.2654    0.0  0.1931  0.3377   True
#                          Qwen3.5-397B-A17B                               gpt-oss-120b  -0.0483 0.4911 -0.1206   0.024  False
# ----------------------------------------------------------------------------------------------------------------------------
#
# safety_mcq_pass_rate: Kruskal-Wallis H=135.82, p=1.754e-25
#                                     Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ============================================================================================================================
#                   group1                                     group2                   meandiff p-adj   lower   upper  reject
# ----------------------------------------------------------------------------------------------------------------------------
#                                GLM-5.1-FP8                                GLM-5.2-FP8   0.0162 0.9994 -0.0632  0.0957  False
#                                GLM-5.1-FP8              Ministral-3-14B-Instruct-2512  -0.2012    0.0 -0.2807 -0.1218   True
#                                GLM-5.1-FP8         Mistral-Large-3-675B-Instruct-2512  -0.0894 0.0144 -0.1689 -0.0099   True
#                                GLM-5.1-FP8     NVIDIA-Nemotron-3-Super-120B-A12B-BF16   -0.015 0.9997 -0.0945  0.0645  False
#                                GLM-5.1-FP8 Nemotron-3-Nano-Omni-30B-A3B-Reasoning-FP8  -0.1194 0.0001 -0.1989 -0.0399   True
#                                GLM-5.1-FP8                Qwen3-30B-A3B-Instruct-2507  -0.1319    0.0 -0.2114 -0.0524   True
#                                GLM-5.1-FP8                          Qwen3.5-397B-A17B  -0.0044    1.0 -0.0839  0.0751  False
#                                GLM-5.1-FP8                               gpt-oss-120b  -0.1331    0.0 -0.2126 -0.0536   True
#                                GLM-5.2-FP8              Ministral-3-14B-Instruct-2512  -0.2175    0.0  -0.297  -0.138   True
#                                GLM-5.2-FP8         Mistral-Large-3-675B-Instruct-2512  -0.1056 0.0013 -0.1851 -0.0261   True
#                                GLM-5.2-FP8     NVIDIA-Nemotron-3-Super-120B-A12B-BF16  -0.0312 0.9522 -0.1107  0.0482  False
#                                GLM-5.2-FP8 Nemotron-3-Nano-Omni-30B-A3B-Reasoning-FP8  -0.1356    0.0 -0.2151 -0.0561   True
#                                GLM-5.2-FP8                Qwen3-30B-A3B-Instruct-2507  -0.1481    0.0 -0.2276 -0.0686   True
#                                GLM-5.2-FP8                          Qwen3.5-397B-A17B  -0.0206 0.9967 -0.1001  0.0589  False
#                                GLM-5.2-FP8                               gpt-oss-120b  -0.1494    0.0 -0.2289 -0.0699   True
#              Ministral-3-14B-Instruct-2512         Mistral-Large-3-675B-Instruct-2512   0.1119 0.0004  0.0324  0.1914   True
#              Ministral-3-14B-Instruct-2512     NVIDIA-Nemotron-3-Super-120B-A12B-BF16   0.1863    0.0  0.1068  0.2657   True
#              Ministral-3-14B-Instruct-2512 Nemotron-3-Nano-Omni-30B-A3B-Reasoning-FP8   0.0819 0.0377  0.0024  0.1614   True
#              Ministral-3-14B-Instruct-2512                Qwen3-30B-A3B-Instruct-2507   0.0694 0.1448 -0.0101  0.1489  False
#              Ministral-3-14B-Instruct-2512                          Qwen3.5-397B-A17B   0.1969    0.0  0.1174  0.2764   True
#              Ministral-3-14B-Instruct-2512                               gpt-oss-120b   0.0681 0.1626 -0.0114  0.1476  False
#         Mistral-Large-3-675B-Instruct-2512     NVIDIA-Nemotron-3-Super-120B-A12B-BF16   0.0744  0.088 -0.0051  0.1539  False
#         Mistral-Large-3-675B-Instruct-2512 Nemotron-3-Nano-Omni-30B-A3B-Reasoning-FP8    -0.03 0.9624 -0.1095  0.0495  False
#         Mistral-Large-3-675B-Instruct-2512                Qwen3-30B-A3B-Instruct-2507  -0.0425 0.7711  -0.122   0.037  False
#         Mistral-Large-3-675B-Instruct-2512                          Qwen3.5-397B-A17B    0.085 0.0256  0.0055  0.1645   True
#         Mistral-Large-3-675B-Instruct-2512                               gpt-oss-120b  -0.0437 0.7414 -0.1232  0.0357  False
#     NVIDIA-Nemotron-3-Super-120B-A12B-BF16 Nemotron-3-Nano-Omni-30B-A3B-Reasoning-FP8  -0.1044 0.0015 -0.1839 -0.0249   True
#     NVIDIA-Nemotron-3-Super-120B-A12B-BF16                Qwen3-30B-A3B-Instruct-2507  -0.1169 0.0002 -0.1964 -0.0374   True
#     NVIDIA-Nemotron-3-Super-120B-A12B-BF16                          Qwen3.5-397B-A17B   0.0106    1.0 -0.0689  0.0901  False
#     NVIDIA-Nemotron-3-Super-120B-A12B-BF16                               gpt-oss-120b  -0.1181 0.0001 -0.1976 -0.0386   True
# Nemotron-3-Nano-Omni-30B-A3B-Reasoning-FP8                Qwen3-30B-A3B-Instruct-2507  -0.0125 0.9999  -0.092   0.067  False
# Nemotron-3-Nano-Omni-30B-A3B-Reasoning-FP8                          Qwen3.5-397B-A17B    0.115 0.0003  0.0355  0.1945   True
# Nemotron-3-Nano-Omni-30B-A3B-Reasoning-FP8                               gpt-oss-120b  -0.0137 0.9998 -0.0932  0.0657  False
#                Qwen3-30B-A3B-Instruct-2507                          Qwen3.5-397B-A17B   0.1275    0.0   0.048   0.207   True
#                Qwen3-30B-A3B-Instruct-2507                               gpt-oss-120b  -0.0012    1.0 -0.0807  0.0782  False
#                          Qwen3.5-397B-A17B                               gpt-oss-120b  -0.1288    0.0 -0.2082 -0.0493   True
# ----------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Correlation between model size and performance
#
# For MoE models, total and active parameter counts can tell very different stories, so both are kept
# and correlated separately. Because parameter counts span two orders of magnitude, correlations are
# computed against `log10(params)` and both **Pearson** (linear) and **Spearman** (monotonic rank,
# more robust with only ~9 models and possible outliers) are reported.

# %%
names = ['GLM-5.1-FP8', 'GLM-5.2-FP8','Ministral-3-14B-Instruct-2512','Mistral-Large-3-675B-Instruct-2512','NVIDIA-Nemotron-3-Super-120B-A12B-BF16','Nemotron-3-Nano-Omni-30B-A3B-Reasoning-FP8','Qwen3-30B-A3B-Instruct-2507','Qwen3.5-397B-A17B','gpt-oss-120b']
total_params = [754,753,14,675,31,120,31,403,120]
active_params = [40,40,14,41,12,3,3,17,5.1]
model_size_dict = {name : {'total_params_b' : total_param, 'active_params_b': active_param} for name, total_param, active_param in zip(names, total_params, active_params)}
model_size_df = pd.DataFrame.from_dict(model_size_dict, orient='index').reset_index(names='model')
model_size_df
# Out:
#                                         model  total_params_b  active_params_b
# 0                                 GLM-5.1-FP8             754             40.0
# 1                                 GLM-5.2-FP8             753             40.0
# 2               Ministral-3-14B-Instruct-2512              14             14.0
# 3          Mistral-Large-3-675B-Instruct-2512             675             41.0
# 4      NVIDIA-Nemotron-3-Super-120B-A12B-BF16              31             12.0
# 5  Nemotron-3-Nano-Omni-30B-A3B-Reasoning-FP8             120              3.0
# 6                 Qwen3-30B-A3B-Instruct-2507              31              3.0
# 7                           Qwen3.5-397B-A17B             403             17.0
# 8                                gpt-oss-120b             120              5.1

# %%
def correlate_size_vs_performance(agg_df, model_size_df, size_col='total_params_b'):
    perf_df = agg_df.groupby(['model', 'metric'])['score'].mean().reset_index()
    merged = perf_df.merge(model_size_df[['model', size_col]], on='model').dropna(subset=[size_col])
    merged['log_size'] = merged[size_col]

    rows = []
    for metric in sorted(merged['metric'].unique()):
        sub = merged[merged['metric'] == metric]
        if sub['model'].nunique() < 3:
            continue
        pearson_r, pearson_p = stats.pearsonr(sub['log_size'], sub['score'])
        spearman_r, spearman_p = stats.spearmanr(sub['log_size'], sub['score'])
        rows.append({
            'metric': metric, 'size_col': size_col, 'n_models': sub['model'].nunique(),
            'pearson_r': pearson_r, 'pearson_p': pearson_p,
            'spearman_r': spearman_r, 'spearman_p': spearman_p,
        })
    return pd.DataFrame(rows), merged

size_corr_total, merged_total = correlate_size_vs_performance(agg_df, model_size_df, 'total_params_b')
size_corr_active, merged_active = correlate_size_vs_performance(agg_df, model_size_df, 'active_params_b')

print('--- vs. total parameters ---')
display(size_corr_total)
print('--- vs. active parameters ---')
display(size_corr_active)
# Out:
# --- vs. total parameters ---
#                        metric        size_col  n_models  pearson_r  pearson_p  \
# 0       general_mcq_pass_rate  total_params_b         9   0.519830   0.151441
# 1  jwp_instruction_fulfilment  total_params_b         9   0.554672   0.121145
# 2        jwp_language_fluency  total_params_b         9   0.673683   0.046648
# 3       jwp_logical_coherence  total_params_b         9   0.626764   0.070865
# 4                 jwp_overall  total_params_b         9   0.750196   0.019892
# 5         jwp_style_alignment  total_params_b         9   0.749273   0.020130
# 6                    sa_score  total_params_b         9   0.315150   0.408773
# 7        safety_mcq_pass_rate  total_params_b         9   0.654078   0.055992
#
#    spearman_r  spearman_p
# 0    0.655485    0.055284
# 1    0.731118    0.025215
# 2    0.739522    0.022768
# 3    0.680696    0.043566
# 4    0.756329    0.018354
# 5    0.756329    0.018354
# 6    0.344550    0.363871
# 7    0.781540    0.012862
# --- vs. active parameters ---
#                        metric         size_col  n_models  pearson_r  \
# 0       general_mcq_pass_rate  active_params_b         9   0.327415
# 1  jwp_instruction_fulfilment  active_params_b         9   0.424939
# 2        jwp_language_fluency  active_params_b         9   0.751233
# 3       jwp_logical_coherence  active_params_b         9   0.696533
# 4                 jwp_overall  active_params_b         9   0.724588
# 5         jwp_style_alignment  active_params_b         9   0.720353
# 6                    sa_score  active_params_b         9   0.171784
# 7        safety_mcq_pass_rate  active_params_b         9   0.563235
#
#    pearson_p  spearman_r  spearman_p
# 0   0.389744    0.411779    0.270805
# 1   0.254233    0.386568    0.304082
# 2   0.019626    0.941210    0.000153
# 3   0.037097    0.714311    0.030617
# 4   0.027233    0.605063    0.084283
# 5   0.028596    0.605063    0.084283
# 6   0.658537    0.075633    0.846654
# 7   0.114307    0.588256    0.095679

# %%
def plot_size_vs_metric(merged, metric, size_col='total_params_b'):
    sub = merged[merged['metric'] == metric]
    plt.figure(figsize=(6, 4.5))
    sns.regplot(data=sub, x='log_size', y='score', scatter_kws={'s': 60})
    for _, row in sub.iterrows():
        plt.annotate(row['model'], (row['log_size'], row['score']), fontsize=8,
                     xytext=(4, 4), textcoords='offset points')
    plt.xlabel(f'{size_col}')
    plt.ylabel(metric)
    plt.title(f'{metric} vs. {size_col}')
    plt.show()

plot_size_vs_metric(merged_total, metric='jwp_overall', size_col='total_params_b')
plot_size_vs_metric(merged_active, metric='jwp_overall', size_col='active_params_b')
